# %% [markdown]
# ## Signed network from text
# #### Twitter is a gold mine of data. Unlike other social platforms, almost every user’s tweets are completely public and pullable. This is a huge plus if you’re trying to get a large amount of data to run analytics on. Twitter data is also pretty specific. Twitter’s API allows you to do complex queries like pulling every tweet about a certain topic within the last twenty minutes, or pull a certain user’s non-retweeted tweets.

# %% [markdown]
# #### Importing

# %%
import requests
import json
import final
import tweepy
import os


from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream

from tweepy import API
from tweepy import Cursor 

from textblob import TextBlob

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import re #regular expression 

#credentianls
import anfalkeys

# %%
r = final.authenticate("anfalkey.json")
ENDPOINT_URL = "https://stream.twitter.com/1.1/statuses/sample.json"

# %% [markdown]
# ##### Collecting tweets

# %%
resp = r.get(ENDPOINT_URL, stream=True)

output_file = open("Tweets.json", "w")

MAX_TWEETS = 1000000
counter = 0
for line in resp:
    if counter > MAX_TWEETS:
        output_file.close()
        break
    if counter % 100:
        print("Saved {} tweets.".format(counter + 1))
    print(line, file=output_file)
    counter += 1
# Out:
# Saved 2 tweets.
# Saved 3 tweets.
# Saved 4 tweets.
# Saved 5 tweets.
# Saved 6 tweets.
# Saved 7 tweets.
# Saved 8 tweets.
# Saved 9 tweets.
# Saved 10 tweets.
# Saved 11 tweets.
# Saved 12 tweets.
# Saved 13 tweets.
# Saved 14 tweets.
# Saved 15 tweets.
# Saved 16 tweets.
# Saved 17 tweets.
# Saved 18 tweets.
# Saved 19 tweets.
# Saved 20 tweets.
# Saved 21 tweets.
# Saved 22 tweets.
# Saved 23 tweets.
# Saved 24 tweets.
# Saved 25 tweets.
# Saved 26 tweets.
# Saved 27 tweets.
# Saved 28 tweets.
# Saved 29 tweets.
# Saved 30 tweets.
# Saved 31 tweets.
# Saved 32 tweets.
# Saved 33 tweets.
# Saved 34 tweets.
# Saved 35 tweets.
# Saved 36 tweets.
# Saved 37 tweets.
# Saved 38 tweets.
# Saved 39 tweets.
# Saved 40 tweets.
# Saved 41 tweets.
# Saved 42 tweets.
# Saved 43 tweets.
# Saved 44 tweets.
# Saved 45 tweets.
# Saved 46 tweets.
# Saved 47 tweets.
# Saved 48 tweets.
# Saved 49 tweets.
# Saved 50 tweets.
# Saved 51 tweets.
# Saved 52 tweets.
# Saved 53 tweets.
# Saved 54 tweets.
# Saved 55 tweets.
# Saved 56 tweets.
# Saved 57 tweets.
# Saved 58 tweets.
# Saved 59 tweets.
# Saved 60 tweets.
# Saved 61 tweets.
# Saved 62 tweets.
# Saved 63 tweets.
# Saved 64 tweets.
# Saved 65 tweets.
# Saved 66 tweets.
# Saved 67 tweets.
# Saved 68 tweets.
# Saved 69 tweets.
# Saved 70 tweets.
# Saved 71 tweets.
# Saved 72 tweets.
# Saved 73 tweets.
# Saved 74 tweets.
# Saved 75 tweets.
# Saved 76 tweets.
# Saved 77 tweets.
# Saved 78 tweets.
# Saved 79 tweets.
# Saved 80 tweets.
# Saved 81 tweets.
# Saved 82 tweets.
# Saved 83 tweets.
# Saved 84 tweets.
# Saved 85 tweets.
# Saved 86 tweets.
# Saved 87 tweets.
# Saved 88 tweets.
# Saved 89 tweets.
# Saved 90 tweets.
# Saved 91 tweets.
# Saved 92 tweets.
# Saved 93 tweets.
# Saved 94 tweets.
# Saved 95 tweets.
# Saved 96 tweets.
# Saved 97 tweets.
# Saved 98 tweets.
# Saved 99 tweets.
# Saved 100 tweets.
# Saved 102 tweets.
# Saved 103 tweets.
# Saved 104 tweets.
# Saved 105 tweets.
# Saved 106 tweets.
# Saved 107 tweets.
# Saved 108 tweets.
# Saved 109 tweets.
# Saved 110 tweets.
# Saved 111 tweets.
# Saved 112 tweets.
# Saved 113 tweets.
# Saved 114 tweets.
# Saved 115 tweets.
# Saved 116 tweets.
# Saved 117 tweets.
# Saved 118 tweets.
# Saved 119 tweets.
# Saved 120 tweets.
# Saved 121 tweets.
# Saved 122 tweets.
# Saved 123 tweets.
# Saved 124 tweets.
# Saved 125 tweets.
# Saved 126 tweets.
# Saved 127 tweets.
# Saved 128 tweets.
# Saved 129 tweets.
# Saved 130 tweets.
# Saved 131 tweets.
# Saved 132 tweets.
# Saved 133 tweets.
# Saved 134 tweets.
# Saved 135 tweets.
# Saved 136 tweets.
# Saved 137 tweets.
# Saved 138 tweets.
# Saved 139 tweets.
# Saved 140 tweets.
# Saved 141 tweets.
# Saved 142 tweets.
# Saved 143 tweets.
# Saved 144 tweets.
# Saved 145 tweets.
# Saved 146 tweets.
# Saved 147 tweets.
# Saved 148 tweets.
# Saved 149 tweets.
# Saved 150 tweets.
# Saved 151 tweets.
# Saved 152 tweets.
# Saved 153 tweets.
# Saved 154 tweets.
# Saved 155 tweets.
# Saved 156 tweets.
# Saved 157 tweets.
# Saved 158 tweets.
# Saved 159 tweets.
# Saved 160 tweets.
# Saved 161 tweets.
# Saved 162 tweets.
# Saved 163 tweets.
# Saved 164 tweets.
# Saved 165 tweets.
# Saved 166 tweets.
# Saved 167 tweets.
# Saved 168 tweets.
# Saved 169 tweets.
# Saved 170 tweets.
# Saved 171 tweets.
# Saved 172 tweets.
# Saved 173 tweets.
# Saved 174 tweets.
# Saved 175 tweets.
# Saved 176 tweets.
# Saved 177 tweets.
# Saved 178 tweets.
# Saved 179 tweets.
# Saved 180 tweets.
# Saved 181 tweets.
# Saved 182 tweets.
# Saved 183 tweets.
# Saved 184 tweets.
# Saved 185 tweets.
# Saved 186 tweets.
# Saved 187 tweets.
# Saved 188 tweets.
# Saved 189 tweets.
# Saved 190 tweets.
# Saved 191 tweets.
# Saved 192 tweets.
# Saved 193 tweets.
# Saved 194 tweets.
# Saved 195 tweets.
# Saved 196 tweets.
# Saved 197 tweets.
# Saved 198 tweets.
# Saved 199 tweets.
# Saved 200 tweets.
# Saved 202 tweets.
# Saved 203 tweets.
# Saved 204 tweets.
# Saved 205 tweets.
# Saved 206 tweets.
# Saved 207 tweets.
# Saved 208 tweets.
# Saved 209 tweets.
# Saved 210 tweets.
# Saved 211 tweets.
# Saved 212 tweets.
# Saved 213 tweets.
# Saved 214 tweets.
# Saved 215 tweets.
# Saved 216 tweets.
# Saved 217 tweets.
# Saved 218 tweets.
# Saved 219 tweets.
# Saved 220 tweets.
# Saved 221 tweets.
# Saved 222 tweets.
# Saved 223 tweets.
# Saved 224 tweets.
# Saved 225 tweets.
# Saved 226 tweets.
# Saved 227 tweets.
# Saved 228 tweets.
# Saved 229 tweets.
# Saved 230 tweets.
# Saved 231 tweets.
# Saved 232 tweets.
# Saved 233 tweets.
# Saved 234 tweets.
# Saved 235 tweets.
# Saved 236 tweets.
# Saved 237 tweets.
# Saved 238 tweets.
# Saved 239 tweets.
# Saved 240 tweets.
# Saved 241 tweets.
# Saved 242 tweets.
# Saved 243 tweets.
# Saved 244 tweets.
# Saved 245 tweets.
# Saved 246 tweets.
# Saved 247 tweets.
# Saved 248 tweets.
# Saved 249 tweets.
# Saved 250 tweets.
# Saved 251 tweets.
# Saved 252 tweets.
# Saved 253 tweets.
# Saved 254 tweets.
# Saved 255 tweets.
# Saved 256 tweets.
# Saved 257 tweets.
# Saved 258 tweets.
# Saved 259 tweets.
# Saved 260 tweets.
# Saved 261 tweets.
# Saved 262 tweets.
# Saved 263 tweets.
# Saved 264 tweets.
# Saved 265 tweets.
# Saved 266 tweets.
# Saved 267 tweets.
# Saved 268 tweets.
# Saved 269 tweets.
# Saved 270 tweets.
# Saved 271 tweets.
# Saved 272 tweets.
# Saved 273 tweets.
# Saved 274 tweets.
# Saved 275 tweets.
# Saved 276 tweets.
# Saved 277 tweets.
# Saved 278 tweets.
# Saved 279 tweets.
# Saved 280 tweets.
# Saved 281 tweets.
# Saved 282 tweets.
# Saved 283 tweets.
# Saved 284 tweets.
# Saved 285 tweets.
# Saved 286 tweets.
# Saved 287 tweets.
# Saved 288 tweets.
# Saved 289 tweets.
# Saved 290 tweets.
# Saved 291 tweets.
# Saved 292 tweets.
# Saved 293 tweets.
# Saved 294 tweets.
# Saved 295 tweets.
# Saved 296 tweets.
# Saved 297 tweets.
# Saved 298 tweets.
# Saved 299 tweets.
# Saved 300 tweets.
# Saved 302 tweets.
# Saved 303 tweets.
# Saved 304 tweets.
# Saved 305 tweets.
# Saved 306 tweets.
# Saved 307 tweets.
# Saved 308 tweets.
# Saved 309 tweets.
# Saved 310 tweets.
# Saved 311 tweets.
# Saved 312 tweets.
# Saved 313 tweets.
# Saved 314 tweets.
# Saved 315 tweets.
# Saved 316 tweets.
# Saved 317 tweets.
# Saved 318 tweets.
# Saved 319 tweets.
# Saved 320 tweets.
# Saved 321 tweets.
# Saved 322 tweets.
# Saved 323 tweets.
# Saved 324 tweets.
# Saved 325 tweets.
# Saved 326 tweets.
# Saved 327 tweets.
# Saved 328 tweets.
# Saved 329 tweets.
# Saved 330 tweets.
# Saved 331 tweets.
# Saved 332 tweets.
# Saved 333 tweets.
# Saved 334 tweets.
# Saved 335 tweets.
# Saved 336 tweets.
# Saved 337 tweets.
# Saved 338 tweets.
# Saved 339 tweets.
# Saved 340 tweets.
# Saved 341 tweets.
# Saved 342 tweets.
# Saved 343 tweets.
# Saved 344 tweets.
# Saved 345 tweets.
# Saved 346 tweets.
# Saved 347 tweets.
# Saved 348 tweets.
# Saved 349 tweets.
# Saved 350 tweets.
# Saved 351 tweets.
# Saved 352 tweets.
# Saved 353 tweets.
# Saved 354 tweets.
# Saved 355 tweets.
# Saved 356 tweets.
# Saved 357 tweets.
# Saved 358 tweets.
# Saved 359 tweets.
# Saved 360 tweets.
# Saved 361 tweets.
# Saved 362 tweets.
# Saved 363 tweets.
# Saved 364 tweets.
# Saved 365 tweets.
# Saved 366 tweets.
# Saved 367 tweets.
# Saved 368 tweets.
# Saved 369 tweets.
# Saved 370 tweets.
# Saved 371 tweets.
# Saved 372 tweets.
# Saved 373 tweets.
# Saved 374 tweets.
# Saved 375 tweets.
# Saved 376 tweets.
# Saved 377 tweets.
# Saved 378 tweets.
# Saved 379 tweets.
# Saved 380 tweets.
# Saved 381 tweets.
# Saved 382 tweets.
# Saved 383 tweets.
# Saved 384 tweets.
# Saved 385 tweets.
# Saved 386 tweets.
# Saved 387 tweets.
# Saved 388 tweets.
# Saved 389 tweets.
# Saved 390 tweets.
# Saved 391 tweets.
# Saved 392 tweets.
# Saved 393 tweets.
# Saved 394 tweets.
# Saved 395 tweets.
# Saved 396 tweets.
# Saved 397 tweets.
# Saved 398 tweets.
# Saved 399 tweets.
# Saved 400 tweets.
# Saved 402 tweets.
# Saved 403 tweets.
# Saved 404 tweets.
# Saved 405 tweets.
# Saved 406 tweets.
# Saved 407 tweets.
# Saved 408 tweets.
# Saved 409 tweets.
# Saved 410 tweets.
# Saved 411 tweets.
# Saved 412 tweets.
# Saved 413 tweets.
# Saved 414 tweets.
# Saved 415 tweets.
# Saved 416 tweets.
# Saved 417 tweets.
# Saved 418 tweets.
# Saved 419 tweets.
# Saved 420 tweets.
# Saved 421 tweets.
# Saved 422 tweets.
# Saved 423 tweets.
# Saved 424 tweets.
# Saved 425 tweets.
# Saved 426 tweets.
# Saved 427 tweets.
# Saved 428 tweets.
# Saved 429 tweets.
# Saved 430 tweets.
# Saved 431 tweets.
# Saved 432 tweets.
# Saved 433 tweets.
# Saved 434 tweets.
# Saved 435 tweets.
# Saved 436 tweets.
# Saved 437 tweets.
# Saved 438 tweets.
# Saved 439 tweets.
# Saved 440 tweets.
# Saved 441 tweets.
# Saved 442 tweets.
# Saved 443 tweets.
# Saved 444 tweets.
# Saved 445 tweets.
# Saved 446 tweets.
# Saved 447 tweets.
# Saved 448 tweets.
# Saved 449 tweets.
# Saved 450 tweets.
# Saved 451 tweets.
# Saved 452 tweets.
# Saved 453 tweets.
# Saved 454 tweets.
# Saved 455 tweets.
# Saved 456 tweets.
# Saved 457 tweets.
# Saved 458 tweets.
# Saved 459 tweets.
# Saved 460 tweets.
# Saved 461 tweets.
# Saved 462 tweets.
# Saved 463 tweets.
# Saved 464 tweets.
# Saved 465 tweets.
# Saved 466 tweets.
# Saved 467 tweets.
# Saved 468 tweets.
# Saved 469 tweets.
# Saved 470 tweets.
# Saved 471 tweets.
# Saved 472 tweets.
# Saved 473 tweets.
# Saved 474 tweets.
# Saved 475 tweets.
# Saved 476 tweets.
# Saved 477 tweets.
# Saved 478 tweets.
# Saved 479 tweets.
# Saved 480 tweets.
# Saved 481 tweets.
# Saved 482 tweets.
# Saved 483 tweets.
# Saved 484 tweets.
# Saved 485 tweets.
# Saved 486 tweets.
# Saved 487 tweets.
# Saved 488 tweets.
# Saved 489 tweets.
# Saved 490 tweets.
# Saved 491 tweets.
# Saved 492 tweets.
# Saved 493 tweets.
# Saved 494 tweets.
# Saved 495 tweets.
# Saved 496 tweets.
# Saved 497 tweets.
# Saved 498 tweets.
# Saved 499 tweets.
# Saved 500 tweets.
# Saved 502 tweets.
# Saved 503 tweets.
# Saved 504 tweets.
# Saved 505 tweets.
# Saved 506 tweets.
# Saved 507 tweets.
# Saved 508 tweets.
# Saved 509 tweets.
# Saved 510 tweets.
# Saved 511 tweets.
# Saved 512 tweets.
# Saved 513 tweets.
# Saved 514 tweets.
# Saved 515 tweets.
# Saved 516 tweets.
# Saved 517 tweets.
# Saved 518 tweets.
# Saved 519 tweets.
# Saved 520 tweets.
# Saved 521 tweets.
# Saved 522 tweets.
# Saved 523 tweets.
# Saved 524 tweets.
# Saved 525 tweets.
# Saved 526 tweets.
# Saved 527 tweets.
# Saved 528 tweets.
# Saved 529 tweets.
# Saved 530 tweets.
# Saved 531 tweets.
# Saved 532 tweets.
# Saved 533 tweets.
# Saved 534 tweets.
# Saved 535 tweets.
# Saved 536 tweets.
# Saved 537 tweets.
# Saved 538 tweets.
# Saved 539 tweets.
# Saved 540 tweets.
# Saved 541 tweets.
# Saved 542 tweets.
# Saved 543 tweets.
# Saved 544 tweets.
# Saved 545 tweets.
# Saved 546 tweets.
# Saved 547 tweets.
# Saved 548 tweets.
# Saved 549 tweets.
# Saved 550 tweets.
# Saved 551 tweets.
# Saved 552 tweets.
# Saved 553 tweets.
# Saved 554 tweets.
# Saved 555 tweets.
# Saved 556 tweets.
# Saved 557 tweets.
# Saved 558 tweets.
# Saved 559 tweets.
# Saved 560 tweets.
# Saved 561 tweets.
# Saved 562 tweets.
# Saved 563 tweets.
# Saved 564 tweets.
# Saved 565 tweets.
# Saved 566 tweets.
# Saved 567 tweets.
# Saved 568 tweets.
# Saved 569 tweets.
# Saved 570 tweets.
# Saved 571 tweets.
# Saved 572 tweets.
# Saved 573 tweets.
# Saved 574 tweets.
# Saved 575 tweets.
# Saved 576 tweets.
# Saved 577 tweets.
# Saved 578 tweets.
# Saved 579 tweets.
# Saved 580 tweets.
# Saved 581 tweets.
# Saved 582 tweets.
# Saved 583 tweets.
# Saved 584 tweets.
# Saved 585 tweets.
# Saved 586 tweets.
# Saved 587 tweets.
# Saved 588 tweets.
# Saved 589 tweets.
# Saved 590 tweets.
# Saved 591 tweets.
# Saved 592 tweets.
# Saved 593 tweets.
# Saved 594 tweets.
# Saved 595 tweets.
# Saved 596 tweets.
# Saved 597 tweets.
# Saved 598 tweets.
# Saved 599 tweets.
# Saved 600 tweets.
# Saved 602 tweets.
# Saved 603 tweets.
# Saved 604 tweets.
# Saved 605 tweets.
# Saved 606 tweets.
# Saved 607 tweets.
# Saved 608 tweets.
# Saved 609 tweets.
# Saved 610 tweets.
# Saved 611 tweets.
# Saved 612 tweets.
# Saved 613 tweets.
# Saved 614 tweets.
# Saved 615 tweets.
# Saved 616 tweets.
# Saved 617 tweets.
# Saved 618 tweets.
# Saved 619 tweets.
# Saved 620 tweets.
# Saved 621 tweets.
# Saved 622 tweets.
# Saved 623 tweets.
# Saved 624 tweets.
# Saved 625 tweets.
# Saved 626 tweets.
# Saved 627 tweets.
# Saved 628 tweets.
# Saved 629 tweets.
# Saved 630 tweets.
# Saved 631 tweets.
# Saved 632 tweets.
# Saved 633 tweets.
# Saved 634 tweets.
# Saved 635 tweets.
# Saved 636 tweets.
# Saved 637 tweets.
# Saved 638 tweets.
# Saved 639 tweets.
# Saved 640 tweets.
# Saved 641 tweets.
# Saved 642 tweets.
# Saved 643 tweets.
# Saved 644 tweets.
# Saved 645 tweets.
# Saved 646 tweets.
# Saved 647 tweets.
# Saved 648 tweets.
# Saved 649 tweets.
# Saved 650 tweets.
# Saved 651 tweets.
# Saved 652 tweets.
# Saved 653 tweets.
# Saved 654 tweets.
# Saved 655 tweets.
# Saved 656 tweets.
# Saved 657 tweets.
# Saved 658 tweets.
# Saved 659 tweets.
# Saved 660 tweets.
# Saved 661 tweets.
# Saved 662 tweets.
# Saved 663 tweets.
# Saved 664 tweets.
# Saved 665 tweets.
# Saved 666 tweets.
# Saved 667 tweets.
# Saved 668 tweets.
# Saved 669 tweets.
# Saved 670 tweets.
# Saved 671 tweets.
# Saved 672 tweets.
# Saved 673 tweets.
# Saved 674 tweets.
# Saved 675 tweets.
# Saved 676 tweets.
# Saved 677 tweets.
# Saved 678 tweets.
# Saved 679 tweets.
# Saved 680 tweets.
# Saved 681 tweets.
# Saved 682 tweets.
# Saved 683 tweets.
# Saved 684 tweets.
# Saved 685 tweets.
# Saved 686 tweets.
# Saved 687 tweets.
# Saved 688 tweets.
# Saved 689 tweets.
# Saved 690 tweets.
# Saved 691 tweets.
# Saved 692 tweets.
# Saved 693 tweets.
# Saved 694 tweets.
# Saved 695 tweets.
# Saved 696 tweets.
# Saved 697 tweets.
# Saved 698 tweets.
# Saved 699 tweets.
# Saved 700 tweets.
# Saved 702 tweets.
# Saved 703 tweets.
# Saved 704 tweets.
# Saved 705 tweets.
# Saved 706 tweets.
# Saved 707 tweets.
# Saved 708 tweets.
# Saved 709 tweets.
# Saved 710 tweets.
# Saved 711 tweets.
# Saved 712 tweets.
# Saved 713 tweets.
# Saved 714 tweets.
# Saved 715 tweets.
# Saved 716 tweets.
# Saved 717 tweets.
# Saved 718 tweets.
# Saved 719 tweets.
# Saved 720 tweets.
# Saved 721 tweets.
# Saved 722 tweets.
# Saved 723 tweets.
# Saved 724 tweets.
# Saved 725 tweets.
# Saved 726 tweets.
# Saved 727 tweets.
# Saved 728 tweets.
# Saved 729 tweets.
# Saved 730 tweets.
# Saved 731 tweets.
# Saved 732 tweets.
# Saved 733 tweets.
# Saved 734 tweets.
# Saved 735 tweets.
# Saved 736 tweets.
# Saved 737 tweets.
# Saved 738 tweets.
# Saved 739 tweets.
# Saved 740 tweets.
# Saved 741 tweets.
# Saved 742 tweets.
# Saved 743 tweets.
# Saved 744 tweets.
# Saved 745 tweets.
# Saved 746 tweets.
# Saved 747 tweets.
# Saved 748 tweets.
# Saved 749 tweets.
# Saved 750 tweets.
# Saved 751 tweets.
# Saved 752 tweets.
# Saved 753 tweets.
# Saved 754 tweets.
# Saved 755 tweets.
# Saved 756 tweets.
# Saved 757 tweets.
# Saved 758 tweets.
# Saved 759 tweets.
# Saved 760 tweets.
# Saved 761 tweets.
# Saved 762 tweets.
# Saved 763 tweets.
# Saved 764 tweets.
# Saved 765 tweets.
# Saved 766 tweets.
# Saved 767 tweets.
# Saved 768 tweets.
# Saved 769 tweets.
# Saved 770 tweets.
# Saved 771 tweets.
# Saved 772 tweets.
# Saved 773 tweets.
# Saved 774 tweets.
# Saved 775 tweets.
# Saved 776 tweets.
# Saved 777 tweets.
# Saved 778 tweets.
# Saved 779 tweets.
# Saved 780 tweets.
# Saved 781 tweets.
# Saved 782 tweets.
# Saved 783 tweets.
# Saved 784 tweets.
# Saved 785 tweets.
# Saved 786 tweets.
# Saved 787 tweets.
# Saved 788 tweets.
# Saved 789 tweets.
# Saved 790 tweets.
# Saved 791 tweets.
# Saved 792 tweets.
# Saved 793 tweets.
# Saved 794 tweets.
# Saved 795 tweets.
# Saved 796 tweets.
# Saved 797 tweets.
# Saved 798 tweets.
# Saved 799 tweets.
# Saved 800 tweets.
# Saved 802 tweets.
# Saved 803 tweets.
# Saved 804 tweets.
# Saved 805 tweets.
# Saved 806 tweets.
# Saved 807 tweets.
# Saved 808 tweets.
# Saved 809 tweets.
# Saved 810 tweets.
# Saved 811 tweets.
# Saved 812 tweets.
# Saved 813 tweets.
# Saved 814 tweets.
# Saved 815 tweets.
# Saved 816 tweets.
# Saved 817 tweets.
# Saved 818 tweets.
# Saved 819 tweets.
# Saved 820 tweets.
# Saved 821 tweets.
# Saved 822 tweets.
# Saved 823 tweets.
# Saved 824 tweets.
# Saved 825 tweets.
# Saved 826 tweets.
# Saved 827 tweets.
# Saved 828 tweets.
# Saved 829 tweets.
# Saved 830 tweets.
# Saved 831 tweets.
# Saved 832 tweets.
# Saved 833 tweets.
# Saved 834 tweets.
# Saved 835 tweets.
# Saved 836 tweets.
# Saved 837 tweets.
# Saved 838 tweets.
# Saved 839 tweets.
# Saved 840 tweets.
# Saved 841 tweets.
# Saved 842 tweets.
# Saved 843 tweets.
# Saved 844 tweets.
# Saved 845 tweets.
# Saved 846 tweets.
# Saved 847 tweets.
# Saved 848 tweets.
# Saved 849 tweets.
# Saved 850 tweets.
# Saved 851 tweets.
# Saved 852 tweets.
# Saved 853 tweets.
# Saved 854 tweets.
# Saved 855 tweets.
# Saved 856 tweets.
# Saved 857 tweets.
# Saved 858 tweets.
# Saved 859 tweets.
# Saved 860 tweets.
# Saved 861 tweets.
# Saved 862 tweets.
# Saved 863 tweets.
# Saved 864 tweets.
# Saved 865 tweets.
# Saved 866 tweets.
# Saved 867 tweets.
# Saved 868 tweets.
# Saved 869 tweets.
# Saved 870 tweets.
# Saved 871 tweets.
# Saved 872 tweets.
# Saved 873 tweets.
# Saved 874 tweets.
# Saved 875 tweets.
# Saved 876 tweets.
# Saved 877 tweets.
# Saved 878 tweets.
# Saved 879 tweets.
# Saved 880 tweets.
# Saved 881 tweets.
# Saved 882 tweets.
# Saved 883 tweets.
# Saved 884 tweets.
# Saved 885 tweets.
# Saved 886 tweets.
# Saved 887 tweets.
# Saved 888 tweets.
# Saved 889 tweets.
# Saved 890 tweets.
# Saved 891 tweets.
# Saved 892 tweets.
# Saved 893 tweets.
# Saved 894 tweets.
# Saved 895 tweets.
# Saved 896 tweets.
# Saved 897 tweets.
# Saved 898 tweets.
# Saved 899 tweets.
# Saved 900 tweets.
# Saved 902 tweets.
# Saved 903 tweets.
# Saved 904 tweets.
# Saved 905 tweets.
# Saved 906 tweets.
# Saved 907 tweets.
# Saved 908 tweets.
# Saved 909 tweets.
# Saved 910 tweets.
# Saved 911 tweets.
# Saved 912 tweets.
# Saved 913 tweets.
# Saved 914 tweets.
# Saved 915 tweets.
# Saved 916 tweets.
# Saved 917 tweets.
# Saved 918 tweets.
# Saved 919 tweets.
# Saved 920 tweets.
# Saved 921 tweets.
# Saved 922 tweets.
# Saved 923 tweets.
# Saved 924 tweets.
# Saved 925 tweets.
# Saved 926 tweets.
# Saved 927 tweets.
# Saved 928 tweets.
# Saved 929 tweets.
# Saved 930 tweets.
# Saved 931 tweets.
# Saved 932 tweets.
# Saved 933 tweets.
# Saved 934 tweets.
# Saved 935 tweets.
# Saved 936 tweets.
# Saved 937 tweets.
# Saved 938 tweets.
# Saved 939 tweets.
# Saved 940 tweets.
# Saved 941 tweets.
# Saved 942 tweets.
# Saved 943 tweets.
# Saved 944 tweets.
# Saved 945 tweets.
# Saved 946 tweets.
# Saved 947 tweets.
# Saved 948 tweets.
# Saved 949 tweets.
# Saved 950 tweets.
# Saved 951 tweets.
# Saved 952 tweets.
# Saved 953 tweets.
# Saved 954 tweets.
# Saved 955 tweets.
# Saved 956 tweets.
# Saved 957 tweets.
# Saved 958 tweets.
# Saved 959 tweets.
# Saved 960 tweets.
# Saved 961 tweets.
# Saved 962 tweets.
# Saved 963 tweets.
# Saved 964 tweets.
# Saved 965 tweets.
# Saved 966 tweets.
# Saved 967 tweets.
# Saved 968 tweets.
# Saved 969 tweets.
# Saved 970 tweets.
# Saved 971 tweets.
# Saved 972 tweets.
# Saved 973 tweets.
# Saved 974 tweets.
# Saved 975 tweets.
# Saved 976 tweets.
# Saved 977 tweets.
# Saved 978 tweets.
# Saved 979 tweets.
# Saved 980 tweets.
# Saved 981 tweets.
# Saved 982 tweets.
# Saved 983 tweets.
# Saved 984 tweets.
# Saved 985 tweets.
# Saved 986 tweets.
# Saved 987 tweets.
# Saved 988 tweets.
# Saved 989 tweets.
# Saved 990 tweets.
# Saved 991 tweets.
# Saved 992 tweets.
# Saved 993 tweets.
# Saved 994 tweets.
# Saved 995 tweets.
# Saved 996 tweets.
# Saved 997 tweets.
# Saved 998 tweets.
# Saved 999 tweets.
# Saved 1000 tweets.
# Saved 1002 tweets.
# Saved 1003 tweets.
# Saved 1004 tweets.
# Saved 1005 tweets.
# Saved 1006 tweets.
# Saved 1007 tweets.
# Saved 1008 tweets.
# Saved 1009 tweets.
# Saved 1010 tweets.
# Saved 1011 tweets.
# Saved 1012 tweets.
# Saved 1013 tweets.
# Saved 1014 tweets.
# Saved 1015 tweets.
# Saved 1016 tweets.
# Saved 1017 tweets.
# Saved 1018 tweets.
# Saved 1019 tweets.
# Saved 1020 tweets.
# Saved 1021 tweets.
# Saved 1022 tweets.
# Saved 1023 tweets.
# Saved 1024 tweets.
# Saved 1025 tweets.
# Saved 1026 tweets.
# Saved 1027 tweets.
# Saved 1028 tweets.
# Saved 1029 tweets.
# Saved 1030 tweets.
# Saved 1031 tweets.
# Saved 1032 tweets.
# Saved 1033 tweets.
# Saved 1034 tweets.
# Saved 1035 tweets.
# Saved 1036 tweets.
# Saved 1037 tweets.
# Saved 1038 tweets.
# Saved 1039 tweets.
# Saved 1040 tweets.
# Saved 1041 tweets.
# Saved 1042 tweets.
# Saved 1043 tweets.
# Saved 1044 tweets.
# Saved 1045 tweets.
# Saved 1046 tweets.
# Saved 1047 tweets.
# Saved 1048 tweets.
# Saved 1049 tweets.
# Saved 1050 tweets.
# Saved 1051 tweets.
# Saved 1052 tweets.
# Saved 1053 tweets.
# Saved 1054 tweets.
# Saved 1055 tweets.
# Saved 1056 tweets.
# Saved 1057 tweets.
# Saved 1058 tweets.
# Saved 1059 tweets.
# Saved 1060 tweets.
# Saved 1061 tweets.
# Saved 1062 tweets.
# Saved 1063 tweets.
# Saved 1064 tweets.
# Saved 1065 tweets.
# Saved 1066 tweets.
# Saved 1067 tweets.
# Saved 1068 tweets.
# Saved 1069 tweets.
# Saved 1070 tweets.
# Saved 1071 tweets.
# Saved 1072 tweets.
# Saved 1073 tweets.
# Saved 1074 tweets.
# Saved 1075 tweets.
# Saved 1076 tweets.
# Saved 1077 tweets.
# Saved 1078 tweets.
# Saved 1079 tweets.
# Saved 1080 tweets.
# Saved 1081 tweets.
# Saved 1082 tweets.
# Saved 1083 tweets.
# Saved 1084 tweets.
# Saved 1085 tweets.
# Saved 1086 tweets.
# Saved 1087 tweets.
# Saved 1088 tweets.
# Saved 1089 tweets.
# Saved 1090 tweets.
# Saved 1091 tweets.
# Saved 1092 tweets.
# Saved 1093 tweets.
# Saved 1094 tweets.
# Saved 1095 tweets.
# Saved 1096 tweets.
# Saved 1097 tweets.
# Saved 1098 tweets.
# Saved 1099 tweets.
# Saved 1100 tweets.
# Saved 1102 tweets.
# Saved 1103 tweets.
# Saved 1104 tweets.
# Saved 1105 tweets.
# Saved 1106 tweets.
# Saved 1107 tweets.
# Saved 1108 tweets.
# Saved 1109 tweets.
# Saved 1110 tweets.
# Saved 1111 tweets.
# Saved 1112 tweets.
# Saved 1113 tweets.
# Saved 1114 tweets.
# Saved 1115 tweets.
# Saved 1116 tweets.
# Saved 1117 tweets.
# Saved 1118 tweets.
# Saved 1119 tweets.
# Saved 1120 tweets.
# Saved 1121 tweets.
# Saved 1122 tweets.
# Saved 1123 tweets.
# Saved 1124 tweets.
# Saved 1125 tweets.
# Saved 1126 tweets.
# Saved 1127 tweets.
# Saved 1128 tweets.
# Saved 1129 tweets.
# Saved 1130 tweets.
# Saved 1131 tweets.
# Saved 1132 tweets.
# Saved 1133 tweets.
# Saved 1134 tweets.
# Saved 1135 tweets.
# Saved 1136 tweets.
# Saved 1137 tweets.
# Saved 1138 tweets.
# Saved 1139 tweets.
# Saved 1140 tweets.
# Saved 1141 tweets.
# Saved 1142 tweets.
# Saved 1143 tweets.
# Saved 1144 tweets.
# Saved 1145 tweets.
# Saved 1146 tweets.
# Saved 1147 tweets.
# Saved 1148 tweets.
# Saved 1149 tweets.
# Saved 1150 tweets.
# Saved 1151 tweets.
# Saved 1152 tweets.
# Saved 1153 tweets.
# Saved 1154 tweets.
# Saved 1155 tweets.
# Saved 1156 tweets.
# Saved 1157 tweets.
# Saved 1158 tweets.
# Saved 1159 tweets.
# Saved 1160 tweets.
# Saved 1161 tweets.
# Saved 1162 tweets.
# Saved 1163 tweets.
# Saved 1164 tweets.
# Saved 1165 tweets.
# Saved 1166 tweets.
# Saved 1167 tweets.
# Saved 1168 tweets.
# Saved 1169 tweets.
# Saved 1170 tweets.
# Saved 1171 tweets.
# Saved 1172 tweets.
# Saved 1173 tweets.
# Saved 1174 tweets.
# Saved 1175 tweets.
# Saved 1176 tweets.
# Saved 1177 tweets.
# Saved 1178 tweets.
# Saved 1179 tweets.
# Saved 1180 tweets.
# Saved 1181 tweets.
# Saved 1182 tweets.
# Saved 1183 tweets.
# Saved 1184 tweets.
# Saved 1185 tweets.
# Saved 1186 tweets.
# Saved 1187 tweets.
# Saved 1188 tweets.
# Saved 1189 tweets.
# Saved 1190 tweets.
# Saved 1191 tweets.
# Saved 1192 tweets.
# Saved 1193 tweets.
# Saved 1194 tweets.
# Saved 1195 tweets.
# Saved 1196 tweets.
# Saved 1197 tweets.
# Saved 1198 tweets.
# Saved 1199 tweets.
# Saved 1200 tweets.
# Saved 1202 tweets.
# Saved 1203 tweets.
# Saved 1204 tweets.
# Saved 1205 tweets.
# Saved 1206 tweets.
# Saved 1207 tweets.
# Saved 1208 tweets.
# Saved 1209 tweets.
# Saved 1210 tweets.
# Saved 1211 tweets.
# Saved 1212 tweets.
# Saved 1213 tweets.
# Saved 1214 tweets.
# Saved 1215 tweets.
# Saved 1216 tweets.
# Saved 1217 tweets.
# Saved 1218 tweets.
# Saved 1219 tweets.
# Saved 1220 tweets.
# Saved 1221 tweets.
# Saved 1222 tweets.
# Saved 1223 tweets.
# Saved 1224 tweets.
# Saved 1225 tweets.
# Saved 1226 tweets.
# Saved 1227 tweets.
# Saved 1228 tweets.
# Saved 1229 tweets.
# Saved 1230 tweets.
# Saved 1231 tweets.
# Saved 1232 tweets.
# Saved 1233 tweets.
# Saved 1234 tweets.
# Saved 1235 tweets.
# Saved 1236 tweets.
# Saved 1237 tweets.
# Saved 1238 tweets.
# Saved 1239 tweets.
# Saved 1240 tweets.
# Saved 1241 tweets.
# Saved 1242 tweets.
# Saved 1243 tweets.
# Saved 1244 tweets.
# Saved 1245 tweets.
# Saved 1246 tweets.
# Saved 1247 tweets.
# Saved 1248 tweets.
# Saved 1249 tweets.
# Saved 1250 tweets.
# Saved 1251 tweets.
# Saved 1252 tweets.
# Saved 1253 tweets.
# Saved 1254 tweets.
# Saved 1255 tweets.
# Saved 1256 tweets.
# Saved 1257 tweets.
# Saved 1258 tweets.
# Saved 1259 tweets.
# Saved 1260 tweets.
# Saved 1261 tweets.
# Saved 1262 tweets.
# Saved 1263 tweets.
# Saved 1264 tweets.
# Saved 1265 tweets.
# Saved 1266 tweets.
# Saved 1267 tweets.
# Saved 1268 tweets.
# Saved 1269 tweets.
# Saved 1270 tweets.
# Saved 1271 tweets.
# Saved 1272 tweets.
# Saved 1273 tweets.
# Saved 1274 tweets.
# Saved 1275 tweets.
# Saved 1276 tweets.
# Saved 1277 tweets.
# Saved 1278 tweets.
# Saved 1279 tweets.
# Saved 1280 tweets.
# Saved 1281 tweets.
# Saved 1282 tweets.
# Saved 1283 tweets.
# Saved 1284 tweets.
# Saved 1285 tweets.
# Saved 1286 tweets.
# Saved 1287 tweets.
# Saved 1288 tweets.
# Saved 1289 tweets.
# Saved 1290 tweets.
# Saved 1291 tweets.
# Saved 1292 tweets.
# Saved 1293 tweets.
# Saved 1294 tweets.
# Saved 1295 tweets.
# Saved 1296 tweets.
# Saved 1297 tweets.
# Saved 1298 tweets.
# Saved 1299 tweets.
# Saved 1300 tweets.
# Saved 1302 tweets.
# Saved 1303 tweets.
# Saved 1304 tweets.
# Saved 1305 tweets.
# Saved 1306 tweets.
# Saved 1307 tweets.
# Saved 1308 tweets.
# Saved 1309 tweets.
# Saved 1310 tweets.
# Saved 1311 tweets.
# Saved 1312 tweets.
# Saved 1313 tweets.
# Saved 1314 tweets.
# Saved 1315 tweets.
# Saved 1316 tweets.
# Saved 1317 tweets.
# Saved 1318 tweets.
# Saved 1319 tweets.
# Saved 1320 tweets.
# Saved 1321 tweets.
# Saved 1322 tweets.
# Saved 1323 tweets.
# Saved 1324 tweets.
# Saved 1325 tweets.
# Saved 1326 tweets.
# Saved 1327 tweets.
# Saved 1328 tweets.
# Saved 1329 tweets.
# Saved 1330 tweets.
# Saved 1331 tweets.
# Saved 1332 tweets.
# Saved 1333 tweets.
# Saved 1334 tweets.
# Saved 1335 tweets.
# Saved 1336 tweets.
# Saved 1337 tweets.
# Saved 1338 tweets.
# Saved 1339 tweets.
# Saved 1340 tweets.
# Saved 1341 tweets.
# Saved 1342 tweets.
# Saved 1343 tweets.
# Saved 1344 tweets.
# Saved 1345 tweets.
# Saved 1346 tweets.
# Saved 1347 tweets.
# Saved 1348 tweets.
# Saved 1349 tweets.
# Saved 1350 tweets.
# Saved 1351 tweets.
# Saved 1352 tweets.
# Saved 1353 tweets.
# Saved 1354 tweets.
# Saved 1355 tweets.
# Saved 1356 tweets.
# Saved 1357 tweets.
# Saved 1358 tweets.
# Saved 1359 tweets.
# Saved 1360 tweets.
# Saved 1361 tweets.
# Saved 1362 tweets.
# Saved 1363 tweets.
# Saved 1364 tweets.
# Saved 1365 tweets.
# Saved 1366 tweets.
# Saved 1367 tweets.
# Saved 1368 tweets.
# Saved 1369 tweets.
# Saved 1370 tweets.
# Saved 1371 tweets.
# Saved 1372 tweets.
# Saved 1373 tweets.
# Saved 1374 tweets.
# Saved 1375 tweets.
# Saved 1376 tweets.
# Saved 1377 tweets.
# Saved 1378 tweets.
# Saved 1379 tweets.
# Saved 1380 tweets.
# Saved 1381 tweets.
# Saved 1382 tweets.
# Saved 1383 tweets.
# Saved 1384 tweets.
# Saved 1385 tweets.
# Saved 1386 tweets.
# Saved 1387 tweets.
# Saved 1388 tweets.
# Saved 1389 tweets.
# Saved 1390 tweets.
# Saved 1391 tweets.
# Saved 1392 tweets.
# Saved 1393 tweets.
# Saved 1394 tweets.
# Saved 1395 tweets.
# Saved 1396 tweets.
# Saved 1397 tweets.
# Saved 1398 tweets.
# Saved 1399 tweets.
# Saved 1400 tweets.
# Saved 1402 tweets.
# Saved 1403 tweets.
# Saved 1404 tweets.
# Saved 1405 tweets.
# Saved 1406 tweets.
# Saved 1407 tweets.
# Saved 1408 tweets.
# Saved 1409 tweets.
# Saved 1410 tweets.
# Saved 1411 tweets.
# Saved 1412 tweets.
# Saved 1413 tweets.
# Saved 1414 tweets.
# Saved 1415 tweets.
# Saved 1416 tweets.
# Saved 1417 tweets.
# Saved 1418 tweets.
# Saved 1419 tweets.
# Saved 1420 tweets.
# Saved 1421 tweets.
# Saved 1422 tweets.
# Saved 1423 tweets.
# Saved 1424 tweets.
# Saved 1425 tweets.
# Saved 1426 tweets.
# Saved 1427 tweets.
# Saved 1428 tweets.
# Saved 1429 tweets.
# Saved 1430 tweets.
# Saved 1431 tweets.
# Saved 1432 tweets.
# Saved 1433 tweets.
# Saved 1434 tweets.
# Saved 1435 tweets.
# Saved 1436 tweets.
# Saved 1437 tweets.
# Saved 1438 tweets.
# Saved 1439 tweets.
# Saved 1440 tweets.
# Saved 1441 tweets.
# Saved 1442 tweets.
# Saved 1443 tweets.
# Saved 1444 tweets.
# Saved 1445 tweets.
# Saved 1446 tweets.
# Saved 1447 tweets.
# Saved 1448 tweets.
# Saved 1449 tweets.
# Saved 1450 tweets.
# Saved 1451 tweets.
# Saved 1452 tweets.
# Saved 1453 tweets.
# Saved 1454 tweets.
# Saved 1455 tweets.
# Saved 1456 tweets.
# Saved 1457 tweets.
# Saved 1458 tweets.
# Saved 1459 tweets.
# Saved 1460 tweets.
# Saved 1461 tweets.
# Saved 1462 tweets.
# Saved 1463 tweets.
# Saved 1464 tweets.
# Saved 1465 tweets.
# Saved 1466 tweets.
# Saved 1467 tweets.
# Saved 1468 tweets.
# Saved 1469 tweets.
# Saved 1470 tweets.
# Saved 1471 tweets.
# Saved 1472 tweets.
# Saved 1473 tweets.
# Saved 1474 tweets.
# Saved 1475 tweets.
# Saved 1476 tweets.
# Saved 1477 tweets.
# Saved 1478 tweets.
# Saved 1479 tweets.
# Saved 1480 tweets.
# Saved 1481 tweets.
# Saved 1482 tweets.
# Saved 1483 tweets.
# Saved 1484 tweets.
# Saved 1485 tweets.
# Saved 1486 tweets.
# Saved 1487 tweets.
# Saved 1488 tweets.
# Saved 1489 tweets.
# Saved 1490 tweets.
# Saved 1491 tweets.
# Saved 1492 tweets.
# Saved 1493 tweets.
# Saved 1494 tweets.
# Saved 1495 tweets.
# Saved 1496 tweets.
# Saved 1497 tweets.
# Saved 1498 tweets.
# Saved 1499 tweets.
# Saved 1500 tweets.
# Saved 1502 tweets.
# Saved 1503 tweets.
# Saved 1504 tweets.
# Saved 1505 tweets.
# Saved 1506 tweets.
# Saved 1507 tweets.
# Saved 1508 tweets.
# Saved 1509 tweets.
# Saved 1510 tweets.
# Saved 1511 tweets.
# Saved 1512 tweets.
# Saved 1513 tweets.
# Saved 1514 tweets.
# Saved 1515 tweets.
# Saved 1516 tweets.
# Saved 1517 tweets.
# Saved 1518 tweets.
# Saved 1519 tweets.
# Saved 1520 tweets.
# Saved 1521 tweets.
# Saved 1522 tweets.
# Saved 1523 tweets.
# Saved 1524 tweets.
# Saved 1525 tweets.
# Saved 1526 tweets.
# Saved 1527 tweets.
# Saved 1528 tweets.
# Saved 1529 tweets.
# Saved 1530 tweets.
# Saved 1531 tweets.
# Saved 1532 tweets.
# Saved 1533 tweets.
# Saved 1534 tweets.
# Saved 1535 tweets.
# Saved 1536 tweets.
# Saved 1537 tweets.
# Saved 1538 tweets.
# Saved 1539 tweets.
# Saved 1540 tweets.
# Saved 1541 tweets.
# Saved 1542 tweets.
# Saved 1543 tweets.
# Saved 1544 tweets.
# Saved 1545 tweets.
# Saved 1546 tweets.
# Saved 1547 tweets.
# Saved 1548 tweets.
# Saved 1549 tweets.
# Saved 1550 tweets.
# Saved 1551 tweets.
# Saved 1552 tweets.
# Saved 1553 tweets.
# Saved 1554 tweets.
# Saved 1555 tweets.
# Saved 1556 tweets.
# Saved 1557 tweets.
# Saved 1558 tweets.
# Saved 1559 tweets.
# Saved 1560 tweets.
# Saved 1561 tweets.
# Saved 1562 tweets.
# Saved 1563 tweets.
# Saved 1564 tweets.
# Saved 1565 tweets.
# Saved 1566 tweets.
# Saved 1567 tweets.
# Saved 1568 tweets.
# Saved 1569 tweets.
# Saved 1570 tweets.
# Saved 1571 tweets.
# Saved 1572 tweets.
# Saved 1573 tweets.
# Saved 1574 tweets.
# Saved 1575 tweets.
# Saved 1576 tweets.
# Saved 1577 tweets.
# Saved 1578 tweets.
# Saved 1579 tweets.
# Saved 1580 tweets.
# Saved 1581 tweets.
# Saved 1582 tweets.
# Saved 1583 tweets.
# Saved 1584 tweets.
# Saved 1585 tweets.
# Saved 1586 tweets.
# Saved 1587 tweets.
# Saved 1588 tweets.
# Saved 1589 tweets.
# Saved 1590 tweets.
# Saved 1591 tweets.
# Saved 1592 tweets.
# Saved 1593 tweets.
# Saved 1594 tweets.
# Saved 1595 tweets.
# Saved 1596 tweets.
# Saved 1597 tweets.
# Saved 1598 tweets.
# Saved 1599 tweets.
# Saved 1600 tweets.
# Saved 1602 tweets.
# Saved 1603 tweets.
# Saved 1604 tweets.
# Saved 1605 tweets.
# Saved 1606 tweets.
# Saved 1607 tweets.
# Saved 1608 tweets.
# Saved 1609 tweets.
# Saved 1610 tweets.
# Saved 1611 tweets.
# Saved 1612 tweets.
# Saved 1613 tweets.
# Saved 1614 tweets.
# Saved 1615 tweets.
# Saved 1616 tweets.
# Saved 1617 tweets.
# Saved 1618 tweets.
# Saved 1619 tweets.
# Saved 1620 tweets.
# Saved 1621 tweets.
# Saved 1622 tweets.
# Saved 1623 tweets.
# Saved 1624 tweets.
# Saved 1625 tweets.
# Saved 1626 tweets.
# Saved 1627 tweets.
# Saved 1628 tweets.
# Saved 1629 tweets.
# Saved 1630 tweets.
# Saved 1631 tweets.
# Saved 1632 tweets.
# Saved 1633 tweets.
# Saved 1634 tweets.
# Saved 1635 tweets.
# Saved 1636 tweets.
# Saved 1637 tweets.
# Saved 1638 tweets.
# Saved 1639 tweets.
# Saved 1640 tweets.
# Saved 1641 tweets.
# Saved 1642 tweets.
# Saved 1643 tweets.
# Saved 1644 tweets.
# Saved 1645 tweets.
# Saved 1646 tweets.
# Saved 1647 tweets.
# Saved 1648 tweets.
# Saved 1649 tweets.
# Saved 1650 tweets.
# Saved 1651 tweets.
# Saved 1652 tweets.
# Saved 1653 tweets.
# Saved 1654 tweets.
# Saved 1655 tweets.
# Saved 1656 tweets.
# Saved 1657 tweets.
# Saved 1658 tweets.
# Saved 1659 tweets.
# Saved 1660 tweets.
# Saved 1661 tweets.
# Saved 1662 tweets.
# Saved 1663 tweets.
# Saved 1664 tweets.
# Saved 1665 tweets.
# Saved 1666 tweets.
# Saved 1667 tweets.
# Saved 1668 tweets.
# Saved 1669 tweets.
# Saved 1670 tweets.
# Saved 1671 tweets.
# Saved 1672 tweets.
# Saved 1673 tweets.
# Saved 1674 tweets.
# Saved 1675 tweets.
# Saved 1676 tweets.
# Saved 1677 tweets.
# Saved 1678 tweets.
# Saved 1679 tweets.
# Saved 1680 tweets.
# Saved 1681 tweets.
# Saved 1682 tweets.
# Saved 1683 tweets.
# Saved 1684 tweets.
# Saved 1685 tweets.
# Saved 1686 tweets.
# Saved 1687 tweets.
# Saved 1688 tweets.
# Saved 1689 tweets.
# Saved 1690 tweets.
# Saved 1691 tweets.
# Saved 1692 tweets.
# Saved 1693 tweets.
# Saved 1694 tweets.
# Saved 1695 tweets.
# Saved 1696 tweets.
# Saved 1697 tweets.
# Saved 1698 tweets.
# Saved 1699 tweets.
# Saved 1700 tweets.
# Saved 1702 tweets.
# Saved 1703 tweets.
# Saved 1704 tweets.
# Saved 1705 tweets.
# Saved 1706 tweets.
# Saved 1707 tweets.
# Saved 1708 tweets.
# Saved 1709 tweets.
# Saved 1710 tweets.
# Saved 1711 tweets.
# Saved 1712 tweets.
# Saved 1713 tweets.
# Saved 1714 tweets.
# Saved 1715 tweets.
# Saved 1716 tweets.
# Saved 1717 tweets.
# Saved 1718 tweets.
# Saved 1719 tweets.
# Saved 1720 tweets.
# Saved 1721 tweets.
# Saved 1722 tweets.
# Saved 1723 tweets.
# Saved 1724 tweets.
# Saved 1725 tweets.
# Saved 1726 tweets.
# Saved 1727 tweets.
# Saved 1728 tweets.
# Saved 1729 tweets.
# Saved 1730 tweets.
# Saved 1731 tweets.
# Saved 1732 tweets.
# Saved 1733 tweets.
# Saved 1734 tweets.
# Saved 1735 tweets.
# Saved 1736 tweets.
# Saved 1737 tweets.
# Saved 1738 tweets.
# Saved 1739 tweets.
# Saved 1740 tweets.
# Saved 1741 tweets.
# Saved 1742 tweets.
# Saved 1743 tweets.
# Saved 1744 tweets.
# Saved 1745 tweets.
# Saved 1746 tweets.
# Saved 1747 tweets.
# Saved 1748 tweets.
# Saved 1749 tweets.
# Saved 1750 tweets.
# Saved 1751 tweets.
# Saved 1752 tweets.
# Saved 1753 tweets.
# Saved 1754 tweets.
# Saved 1755 tweets.
# Saved 1756 tweets.
# Saved 1757 tweets.
# Saved 1758 tweets.
# Saved 1759 tweets.
# Saved 1760 tweets.
# Saved 1761 tweets.
# Saved 1762 tweets.
# Saved 1763 tweets.
# Saved 1764 tweets.
# Saved 1765 tweets.
# Saved 1766 tweets.
# Saved 1767 tweets.
# Saved 1768 tweets.
# Saved 1769 tweets.
# Saved 1770 tweets.
# Saved 1771 tweets.
# Saved 1772 tweets.
# Saved 1773 tweets.
# Saved 1774 tweets.
# Saved 1775 tweets.
# Saved 1776 tweets.
# Saved 1777 tweets.
# Saved 1778 tweets.
# Saved 1779 tweets.
# Saved 1780 tweets.
# Saved 1781 tweets.
# Saved 1782 tweets.
# Saved 1783 tweets.
# Saved 1784 tweets.
# Saved 1785 tweets.
# Saved 1786 tweets.
# Saved 1787 tweets.
# Saved 1788 tweets.
# Saved 1789 tweets.
# Saved 1790 tweets.
# Saved 1791 tweets.
# Saved 1792 tweets.
# Saved 1793 tweets.
# Saved 1794 tweets.
# Saved 1795 tweets.
# Saved 1796 tweets.
# Saved 1797 tweets.
# Saved 1798 tweets.
# Saved 1799 tweets.
# Saved 1800 tweets.
# Saved 1802 tweets.
# Saved 1803 tweets.
# Saved 1804 tweets.
# Saved 1805 tweets.
# Saved 1806 tweets.
# Saved 1807 tweets.
# Saved 1808 tweets.
# Saved 1809 tweets.
# Saved 1810 tweets.
# Saved 1811 tweets.
# Saved 1812 tweets.
# Saved 1813 tweets.
# Saved 1814 tweets.
# Saved 1815 tweets.
# Saved 1816 tweets.
# Saved 1817 tweets.
# Saved 1818 tweets.
# Saved 1819 tweets.
# Saved 1820 tweets.
# Saved 1821 tweets.
# Saved 1822 tweets.
# Saved 1823 tweets.
# Saved 1824 tweets.
# Saved 1825 tweets.
# Saved 1826 tweets.
# Saved 1827 tweets.
# Saved 1828 tweets.
# Saved 1829 tweets.
# Saved 1830 tweets.
# Saved 1831 tweets.
# Saved 1832 tweets.
# Saved 1833 tweets.
# Saved 1834 tweets.
# Saved 1835 tweets.
# Saved 1836 tweets.
# Saved 1837 tweets.
# Saved 1838 tweets.
# Saved 1839 tweets.
# Saved 1840 tweets.
# Saved 1841 tweets.
# Saved 1842 tweets.
# Saved 1843 tweets.
# Saved 1844 tweets.
# Saved 1845 tweets.
# Saved 1846 tweets.
# Saved 1847 tweets.
# Saved 1848 tweets.
# Saved 1849 tweets.
# Saved 1850 tweets.
# Saved 1851 tweets.
# Saved 1852 tweets.
# Saved 1853 tweets.
# Saved 1854 tweets.
# Saved 1855 tweets.
# Saved 1856 tweets.
# Saved 1857 tweets.
# Saved 1858 tweets.
# Saved 1859 tweets.
# Saved 1860 tweets.
# Saved 1861 tweets.
# Saved 1862 tweets.
# Saved 1863 tweets.
# Saved 1864 tweets.
# Saved 1865 tweets.
# Saved 1866 tweets.
# Saved 1867 tweets.
# Saved 1868 tweets.
# Saved 1869 tweets.
# Saved 1870 tweets.
# Saved 1871 tweets.
# Saved 1872 tweets.
# Saved 1873 tweets.
# Saved 1874 tweets.
# Saved 1875 tweets.
# Saved 1876 tweets.
# Saved 1877 tweets.
# Saved 1878 tweets.
# Saved 1879 tweets.
# Saved 1880 tweets.
# Saved 1881 tweets.
# Saved 1882 tweets.
# Saved 1883 tweets.
# Saved 1884 tweets.
# Saved 1885 tweets.
# Saved 1886 tweets.
# Saved 1887 tweets.
# Saved 1888 tweets.
# Saved 1889 tweets.
# Saved 1890 tweets.
# Saved 1891 tweets.
# Saved 1892 tweets.
# Saved 1893 tweets.
# Saved 1894 tweets.
# Saved 1895 tweets.
# Saved 1896 tweets.
# Saved 1897 tweets.
# Saved 1898 tweets.
# Saved 1899 tweets.
# Saved 1900 tweets.
# Saved 1902 tweets.
# Saved 1903 tweets.
# Saved 1904 tweets.
# Saved 1905 tweets.
# Saved 1906 tweets.
# Saved 1907 tweets.
# Saved 1908 tweets.
# Saved 1909 tweets.
# Saved 1910 tweets.
# Saved 1911 tweets.
# Saved 1912 tweets.
# Saved 1913 tweets.
# Saved 1914 tweets.
# Saved 1915 tweets.
# Saved 1916 tweets.
# Saved 1917 tweets.
# Saved 1918 tweets.
# Saved 1919 tweets.
# Saved 1920 tweets.
# Saved 1921 tweets.
# Saved 1922 tweets.
# Saved 1923 tweets.
# Saved 1924 tweets.
# Saved 1925 tweets.
# Saved 1926 tweets.
# Saved 1927 tweets.
# Saved 1928 tweets.
# Saved 1929 tweets.
# Saved 1930 tweets.
# Saved 1931 tweets.
# Saved 1932 tweets.
# Saved 1933 tweets.
# Saved 1934 tweets.
# Saved 1935 tweets.
# Saved 1936 tweets.
# Saved 1937 tweets.
# Saved 1938 tweets.
# Saved 1939 tweets.
# Saved 1940 tweets.
# Saved 1941 tweets.
# Saved 1942 tweets.
# Saved 1943 tweets.
# Saved 1944 tweets.
# Saved 1945 tweets.
# Saved 1946 tweets.
# Saved 1947 tweets.
# Saved 1948 tweets.
# Saved 1949 tweets.
# Saved 1950 tweets.
# Saved 1951 tweets.
# Saved 1952 tweets.
# Saved 1953 tweets.
# Saved 1954 tweets.
# Saved 1955 tweets.
# Saved 1956 tweets.
# Saved 1957 tweets.
# Saved 1958 tweets.
# Saved 1959 tweets.
# Saved 1960 tweets.
# Saved 1961 tweets.
# Saved 1962 tweets.
# Saved 1963 tweets.
# Saved 1964 tweets.
# Saved 1965 tweets.
# Saved 1966 tweets.
# Saved 1967 tweets.
# Saved 1968 tweets.
# Saved 1969 tweets.
# Saved 1970 tweets.
# Saved 1971 tweets.
# Saved 1972 tweets.
# Saved 1973 tweets.
# Saved 1974 tweets.
# Saved 1975 tweets.
# Saved 1976 tweets.
# Saved 1977 tweets.
# Saved 1978 tweets.
# Saved 1979 tweets.
# Saved 1980 tweets.
# Saved 1981 tweets.
# Saved 1982 tweets.
# Saved 1983 tweets.
# Saved 1984 tweets.
# Saved 1985 tweets.
# Saved 1986 tweets.
# Saved 1987 tweets.
# Saved 1988 tweets.
# Saved 1989 tweets.
# Saved 1990 tweets.
# Saved 1991 tweets.
# Saved 1992 tweets.
# Saved 1993 tweets.
# Saved 1994 tweets.
# Saved 1995 tweets.
# Saved 1996 tweets.
# Saved 1997 tweets.
# Saved 1998 tweets.
# Saved 1999 tweets.
# Saved 2000 tweets.
# Saved 2002 tweets.
# Saved 2003 tweets.
# Saved 2004 tweets.
# Saved 2005 tweets.
# Saved 2006 tweets.
# Saved 2007 tweets.
# Saved 2008 tweets.
# Saved 2009 tweets.
# Saved 2010 tweets.
# Saved 2011 tweets.
# Saved 2012 tweets.
# Saved 2013 tweets.
# Saved 2014 tweets.
# Saved 2015 tweets.
# Saved 2016 tweets.
# Saved 2017 tweets.
# Saved 2018 tweets.
# Saved 2019 tweets.
# Saved 2020 tweets.
# Saved 2021 tweets.
# Saved 2022 tweets.
# Saved 2023 tweets.
# Saved 2024 tweets.
# Saved 2025 tweets.
# Saved 2026 tweets.
# Saved 2027 tweets.
# Saved 2028 tweets.
# Saved 2029 tweets.
# Saved 2030 tweets.
# Saved 2031 tweets.
# Saved 2032 tweets.
# Saved 2033 tweets.
# Saved 2034 tweets.
# Saved 2035 tweets.
# Saved 2036 tweets.
# Saved 2037 tweets.
# Saved 2038 tweets.
# Saved 2039 tweets.
# Saved 2040 tweets.
# Saved 2041 tweets.
# Saved 2042 tweets.
# Saved 2043 tweets.
# Saved 2044 tweets.
# Saved 2045 tweets.
# Saved 2046 tweets.
# Saved 2047 tweets.
# Saved 2048 tweets.
# Saved 2049 tweets.
# Saved 2050 tweets.
# Saved 2051 tweets.
# Saved 2052 tweets.
# Saved 2053 tweets.
# Saved 2054 tweets.
# Saved 2055 tweets.
# Saved 2056 tweets.
# Saved 2057 tweets.
# Saved 2058 tweets.
# Saved 2059 tweets.
# Saved 2060 tweets.
# Saved 2061 tweets.
# Saved 2062 tweets.
# Saved 2063 tweets.
# Saved 2064 tweets.
# Saved 2065 tweets.
# Saved 2066 tweets.
# Saved 2067 tweets.
# Saved 2068 tweets.
# Saved 2069 tweets.
# Saved 2070 tweets.
# Saved 2071 tweets.
# Saved 2072 tweets.
# Saved 2073 tweets.
# Saved 2074 tweets.
# Saved 2075 tweets.
# Saved 2076 tweets.
# Saved 2077 tweets.
# Saved 2078 tweets.
# Saved 2079 tweets.
# Saved 2080 tweets.
# Saved 2081 tweets.
# Saved 2082 tweets.
# Saved 2083 tweets.
# Saved 2084 tweets.
# Saved 2085 tweets.
# Saved 2086 tweets.
# Saved 2087 tweets.
# Saved 2088 tweets.
# Saved 2089 tweets.
# Saved 2090 tweets.
# Saved 2091 tweets.
# Saved 2092 tweets.
# Saved 2093 tweets.
# Saved 2094 tweets.
# Saved 2095 tweets.
# Saved 2096 tweets.
# Saved 2097 tweets.
# Saved 2098 tweets.
# Saved 2099 tweets.
# Saved 2100 tweets.
# Saved 2102 tweets.
# Saved 2103 tweets.
# Saved 2104 tweets.
# Saved 2105 tweets.
# Saved 2106 tweets.
# Saved 2107 tweets.
# Saved 2108 tweets.
# Saved 2109 tweets.
# Saved 2110 tweets.
# Saved 2111 tweets.
# Saved 2112 tweets.
# Saved 2113 tweets.
# Saved 2114 tweets.
# Saved 2115 tweets.
# Saved 2116 tweets.
# Saved 2117 tweets.
# Saved 2118 tweets.
# Saved 2119 tweets.
# Saved 2120 tweets.
# Saved 2121 tweets.
# Saved 2122 tweets.
# Saved 2123 tweets.
# Saved 2124 tweets.
# Saved 2125 tweets.
# Saved 2126 tweets.
# Saved 2127 tweets.
# Saved 2128 tweets.
# Saved 2129 tweets.
# Saved 2130 tweets.
# Saved 2131 tweets.
# Saved 2132 tweets.
# Saved 2133 tweets.
# Saved 2134 tweets.
# Saved 2135 tweets.
# Saved 2136 tweets.
# Saved 2137 tweets.
# Saved 2138 tweets.
# Saved 2139 tweets.
# Saved 2140 tweets.
# Saved 2141 tweets.
# Saved 2142 tweets.
# Saved 2143 tweets.
# Saved 2144 tweets.
# Saved 2145 tweets.
# Saved 2146 tweets.
# Saved 2147 tweets.
# Saved 2148 tweets.
# Saved 2149 tweets.
# Saved 2150 tweets.
# Saved 2151 tweets.
# Saved 2152 tweets.
# Saved 2153 tweets.
# Saved 2154 tweets.
# Saved 2155 tweets.
# Saved 2156 tweets.
# Saved 2157 tweets.
# Saved 2158 tweets.
# Saved 2159 tweets.
# Saved 2160 tweets.
# Saved 2161 tweets.
# Saved 2162 tweets.
# Saved 2163 tweets.
# Saved 2164 tweets.
# Saved 2165 tweets.
# Saved 2166 tweets.
# Saved 2167 tweets.
# Saved 2168 tweets.
# Saved 2169 tweets.
# Saved 2170 tweets.
# Saved 2171 tweets.
# Saved 2172 tweets.
# Saved 2173 tweets.
# Saved 2174 tweets.
# Saved 2175 tweets.
# Saved 2176 tweets.
# Saved 2177 tweets.
# Saved 2178 tweets.
# Saved 2179 tweets.
# Saved 2180 tweets.
# Saved 2181 tweets.
# Saved 2182 tweets.
# Saved 2183 tweets.
# Saved 2184 tweets.
# Saved 2185 tweets.
# Saved 2186 tweets.
# Saved 2187 tweets.
# Saved 2188 tweets.
# Saved 2189 tweets.
# Saved 2190 tweets.
# Saved 2191 tweets.
# Saved 2192 tweets.
# Saved 2193 tweets.
# Saved 2194 tweets.
# Saved 2195 tweets.
# Saved 2196 tweets.
# Saved 2197 tweets.
# Saved 2198 tweets.
# Saved 2199 tweets.
# Saved 2200 tweets.
# Saved 2202 tweets.
# Saved 2203 tweets.
# Saved 2204 tweets.
# Saved 2205 tweets.
# Saved 2206 tweets.
# Saved 2207 tweets.
# Saved 2208 tweets.
# Saved 2209 tweets.
# Saved 2210 tweets.
# Saved 2211 tweets.
# Saved 2212 tweets.
# Saved 2213 tweets.
# Saved 2214 tweets.
# Saved 2215 tweets.
# Saved 2216 tweets.
# Saved 2217 tweets.
# Saved 2218 tweets.
# Saved 2219 tweets.
# Saved 2220 tweets.
# Saved 2221 tweets.
# Saved 2222 tweets.
# Saved 2223 tweets.
# Saved 2224 tweets.
# Saved 2225 tweets.
# Saved 2226 tweets.
# Saved 2227 tweets.
# Saved 2228 tweets.
# Saved 2229 tweets.
# Saved 2230 tweets.
# Saved 2231 tweets.
# Saved 2232 tweets.
# Saved 2233 tweets.
# Saved 2234 tweets.
# Saved 2235 tweets.
# Saved 2236 tweets.
# Saved 2237 tweets.
# Saved 2238 tweets.
# Saved 2239 tweets.
# Saved 2240 tweets.
# Saved 2241 tweets.
# Saved 2242 tweets.
# Saved 2243 tweets.
# Saved 2244 tweets.
# Saved 2245 tweets.
# Saved 2246 tweets.
# Saved 2247 tweets.
# Saved 2248 tweets.
# Saved 2249 tweets.
# Saved 2250 tweets.
# Saved 2251 tweets.
# Saved 2252 tweets.
# Saved 2253 tweets.
# Saved 2254 tweets.
# Saved 2255 tweets.
# Saved 2256 tweets.
# Saved 2257 tweets.
# Saved 2258 tweets.
# Saved 2259 tweets.
# Saved 2260 tweets.
# Saved 2261 tweets.
# Saved 2262 tweets.
# Saved 2263 tweets.
# Saved 2264 tweets.
# Saved 2265 tweets.
# Saved 2266 tweets.
# Saved 2267 tweets.
# Saved 2268 tweets.
# Saved 2269 tweets.
# Saved 2270 tweets.
# Saved 2271 tweets.
# Saved 2272 tweets.
# Saved 2273 tweets.
# Saved 2274 tweets.
# Saved 2275 tweets.
# Saved 2276 tweets.
# Saved 2277 tweets.
# Saved 2278 tweets.
# Saved 2279 tweets.
# Saved 2280 tweets.
# Saved 2281 tweets.
# Saved 2282 tweets.
# Saved 2283 tweets.
# Saved 2284 tweets.
# Saved 2285 tweets.
# Saved 2286 tweets.
# Saved 2287 tweets.
# Saved 2288 tweets.
# Saved 2289 tweets.
# Saved 2290 tweets.
# Saved 2291 tweets.
# Saved 2292 tweets.
# Saved 2293 tweets.
# Saved 2294 tweets.
# Saved 2295 tweets.
# Saved 2296 tweets.
# Saved 2297 tweets.
# Saved 2298 tweets.
# Saved 2299 tweets.
# Saved 2300 tweets.
# Saved 2302 tweets.
# Saved 2303 tweets.
# Saved 2304 tweets.
# Saved 2305 tweets.
# Saved 2306 tweets.
# Saved 2307 tweets.
# Saved 2308 tweets.
# Saved 2309 tweets.
# Saved 2310 tweets.
# Saved 2311 tweets.
# Saved 2312 tweets.
# Saved 2313 tweets.
# Saved 2314 tweets.
# Saved 2315 tweets.
# Saved 2316 tweets.
# Saved 2317 tweets.
# Saved 2318 tweets.
# Saved 2319 tweets.
# Saved 2320 tweets.
# Saved 2321 tweets.
# Saved 2322 tweets.
# Saved 2323 tweets.
# Saved 2324 tweets.
# Saved 2325 tweets.
# Saved 2326 tweets.
# Saved 2327 tweets.
# Saved 2328 tweets.
# Saved 2329 tweets.
# Saved 2330 tweets.
# Saved 2331 tweets.
# Saved 2332 tweets.
# Saved 2333 tweets.
# Saved 2334 tweets.
# Saved 2335 tweets.
# Saved 2336 tweets.
# Saved 2337 tweets.
# Saved 2338 tweets.
# Saved 2339 tweets.
# Saved 2340 tweets.
# Saved 2341 tweets.
# Saved 2342 tweets.
# Saved 2343 tweets.
# Saved 2344 tweets.
# Saved 2345 tweets.
# Saved 2346 tweets.
# Saved 2347 tweets.
# Saved 2348 tweets.
# Saved 2349 tweets.
# Saved 2350 tweets.
# Saved 2351 tweets.
# Saved 2352 tweets.
# Saved 2353 tweets.
# Saved 2354 tweets.
# Saved 2355 tweets.
# Saved 2356 tweets.
# Saved 2357 tweets.
# Saved 2358 tweets.
# Saved 2359 tweets.
# Saved 2360 tweets.
# Saved 2361 tweets.
# Saved 2362 tweets.
# Saved 2363 tweets.
# Saved 2364 tweets.
# Saved 2365 tweets.
# Saved 2366 tweets.
# Saved 2367 tweets.
# Saved 2368 tweets.
# Saved 2369 tweets.
# Saved 2370 tweets.
# Saved 2371 tweets.
# Saved 2372 tweets.
# Saved 2373 tweets.
# Saved 2374 tweets.
# Saved 2375 tweets.
# Saved 2376 tweets.
# Saved 2377 tweets.
# Saved 2378 tweets.
# Saved 2379 tweets.
# Saved 2380 tweets.
# Saved 2381 tweets.
# Saved 2382 tweets.
# Saved 2383 tweets.
# Saved 2384 tweets.
# Saved 2385 tweets.
# Saved 2386 tweets.
# Saved 2387 tweets.
# Saved 2388 tweets.
# Saved 2389 tweets.
# Saved 2390 tweets.
# Saved 2391 tweets.
# Saved 2392 tweets.
# Saved 2393 tweets.
# Saved 2394 tweets.
# Saved 2395 tweets.
# Saved 2396 tweets.
# Saved 2397 tweets.
# Saved 2398 tweets.
# Saved 2399 tweets.
# Saved 2400 tweets.
# Saved 2402 tweets.
# Saved 2403 tweets.
# Saved 2404 tweets.
# Saved 2405 tweets.
# Saved 2406 tweets.
# Saved 2407 tweets.
# Saved 2408 tweets.
# Saved 2409 tweets.
# Saved 2410 tweets.
# Saved 2411 tweets.
# Saved 2412 tweets.
# Saved 2413 tweets.
# Saved 2414 tweets.
# Saved 2415 tweets.
# Saved 2416 tweets.
# Saved 2417 tweets.
# Saved 2418 tweets.
# Saved 2419 tweets.
# Saved 2420 tweets.
# Saved 2421 tweets.
# Saved 2422 tweets.
# Saved 2423 tweets.
# Saved 2424 tweets.
# Saved 2425 tweets.
# Saved 2426 tweets.
# Saved 2427 tweets.
# Saved 2428 tweets.
# Saved 2429 tweets.
# Saved 2430 tweets.
# Saved 2431 tweets.
# Saved 2432 tweets.
# Saved 2433 tweets.
# Saved 2434 tweets.
# Saved 2435 tweets.
# Saved 2436 tweets.
# Saved 2437 tweets.
# Saved 2438 tweets.
# Saved 2439 tweets.
# Saved 2440 tweets.
# Saved 2441 tweets.
# Saved 2442 tweets.
# Saved 2443 tweets.
# Saved 2444 tweets.
# Saved 2445 tweets.
# Saved 2446 tweets.
# Saved 2447 tweets.
# Saved 2448 tweets.
# Saved 2449 tweets.
# Saved 2450 tweets.
# Saved 2451 tweets.
# Saved 2452 tweets.
# Saved 2453 tweets.
# Saved 2454 tweets.
# Saved 2455 tweets.
# Saved 2456 tweets.
# Saved 2457 tweets.
# Saved 2458 tweets.
# Saved 2459 tweets.
# Saved 2460 tweets.
# Saved 2461 tweets.
# Saved 2462 tweets.
# Saved 2463 tweets.
# Saved 2464 tweets.
# Saved 2465 tweets.
# Saved 2466 tweets.
# Saved 2467 tweets.
# Saved 2468 tweets.
# Saved 2469 tweets.
# Saved 2470 tweets.
# Saved 2471 tweets.
# Saved 2472 tweets.
# Saved 2473 tweets.
# Saved 2474 tweets.
# Saved 2475 tweets.
# Saved 2476 tweets.
# Saved 2477 tweets.
# Saved 2478 tweets.
# Saved 2479 tweets.
# Saved 2480 tweets.
# Saved 2481 tweets.
# Saved 2482 tweets.
# Saved 2483 tweets.
# Saved 2484 tweets.
# Saved 2485 tweets.
# Saved 2486 tweets.
# Saved 2487 tweets.
# Saved 2488 tweets.
# Saved 2489 tweets.
# Saved 2490 tweets.
# Saved 2491 tweets.
# Saved 2492 tweets.
# Saved 2493 tweets.
# Saved 2494 tweets.
# Saved 2495 tweets.
# Saved 2496 tweets.
# Saved 2497 tweets.
# Saved 2498 tweets.
# Saved 2499 tweets.
# Saved 2500 tweets.
# Saved 2502 tweets.
# Saved 2503 tweets.
# Saved 2504 tweets.
# Saved 2505 tweets.
# Saved 2506 tweets.
# Saved 2507 tweets.
# Saved 2508 tweets.
# Saved 2509 tweets.
# Saved 2510 tweets.
# Saved 2511 tweets.
# Saved 2512 tweets.
# Saved 2513 tweets.
# Saved 2514 tweets.
# Saved 2515 tweets.
# Saved 2516 tweets.
# Saved 2517 tweets.
# Saved 2518 tweets.
# Saved 2519 tweets.
# Saved 2520 tweets.
# Saved 2521 tweets.
# Saved 2522 tweets.
# Saved 2523 tweets.
# Saved 2524 tweets.
# Saved 2525 tweets.
# Saved 2526 tweets.
# Saved 2527 tweets.
# Saved 2528 tweets.
# Saved 2529 tweets.
# Saved 2530 tweets.
# Saved 2531 tweets.
# Saved 2532 tweets.
# Saved 2533 tweets.
# Saved 2534 tweets.
# Saved 2535 tweets.
# Saved 2536 tweets.
# Saved 2537 tweets.
# Saved 2538 tweets.
# Saved 2539 tweets.
# Saved 2540 tweets.
# Saved 2541 tweets.
# Saved 2542 tweets.
# Saved 2543 tweets.
# Saved 2544 tweets.
# Saved 2545 tweets.
# Saved 2546 tweets.
# Saved 2547 tweets.
# Saved 2548 tweets.
# Saved 2549 tweets.
# Saved 2550 tweets.
# Saved 2551 tweets.
# Saved 2552 tweets.
# Saved 2553 tweets.
# Saved 2554 tweets.
# Saved 2555 tweets.
# Saved 2556 tweets.
# Saved 2557 tweets.
# Saved 2558 tweets.
# Saved 2559 tweets.
# Saved 2560 tweets.
# Saved 2561 tweets.
# Saved 2562 tweets.
# Saved 2563 tweets.
# Saved 2564 tweets.
# Saved 2565 tweets.
# Saved 2566 tweets.
# Saved 2567 tweets.
# Saved 2568 tweets.
# Saved 2569 tweets.
# Saved 2570 tweets.
# Saved 2571 tweets.
# Saved 2572 tweets.
# Saved 2573 tweets.
# Saved 2574 tweets.
# Saved 2575 tweets.
# Saved 2576 tweets.
# Saved 2577 tweets.
# Saved 2578 tweets.
# Saved 2579 tweets.
# Saved 2580 tweets.
# Saved 2581 tweets.
# Saved 2582 tweets.
# Saved 2583 tweets.
# Saved 2584 tweets.
# Saved 2585 tweets.
# Saved 2586 tweets.
# Saved 2587 tweets.
# Saved 2588 tweets.
# Saved 2589 tweets.
# Saved 2590 tweets.
# Saved 2591 tweets.
# Saved 2592 tweets.
# Saved 2593 tweets.
# Saved 2594 tweets.
# Saved 2595 tweets.
# Saved 2596 tweets.
# Saved 2597 tweets.
# Saved 2598 tweets.
# Saved 2599 tweets.
# Saved 2600 tweets.
# Saved 2602 tweets.
# Saved 2603 tweets.
# Saved 2604 tweets.
# Saved 2605 tweets.
# Saved 2606 tweets.
# Saved 2607 tweets.
# Saved 2608 tweets.
# Saved 2609 tweets.
# Saved 2610 tweets.
# ...
# Saved 76003 tweets.
# Saved 76004 tweets.
# Saved 76005 tweets.
# Saved 76006 tweets.
# Saved 76007 tweets.
# Saved 76008 tweets.
# Saved 76009 tweets.
# Saved 76010 tweets.
# Saved 76011 tweets.
# Saved 76012 tweets.
# Saved 76013 tweets.
# Saved 76014 tweets.
# Saved 76015 tweets.
# Saved 76016 tweets.
# Saved 76017 tweets.
# Saved 76018 tweets.
# Saved 76019 tweets.
# Saved 76020 tweets.
# Saved 76021 tweets.
# Saved 76022 tweets.
# Saved 76023 tweets.
# Saved 76024 tweets.
# Saved 76025 tweets.
# Saved 76026 tweets.
# Saved 76027 tweets.
# Saved 76028 tweets.
# Saved 76029 tweets.
# Saved 76030 tweets.
# Saved 76031 tweets.
# Saved 76032 tweets.
# Saved 76033 tweets.
# Saved 76034 tweets.
# Saved 76035 tweets.
# Saved 76036 tweets.
# Saved 76037 tweets.
# Saved 76038 tweets.
# Saved 76039 tweets.
# Saved 76040 tweets.
# Saved 76041 tweets.
# Saved 76042 tweets.
# Saved 76043 tweets.
# Saved 76044 tweets.
# Saved 76045 tweets.
# Saved 76046 tweets.
# Saved 76047 tweets.
# Saved 76048 tweets.
# Saved 76049 tweets.
# Saved 76050 tweets.
# Saved 76051 tweets.
# Saved 76052 tweets.
# Saved 76053 tweets.
# Saved 76054 tweets.
# Saved 76055 tweets.
# Saved 76056 tweets.
# Saved 76057 tweets.
# Saved 76058 tweets.
# Saved 76059 tweets.
# Saved 76060 tweets.
# Saved 76061 tweets.
# Saved 76062 tweets.
# Saved 76063 tweets.
# Saved 76064 tweets.
# Saved 76065 tweets.
# Saved 76066 tweets.
# Saved 76067 tweets.
# Saved 76068 tweets.
# Saved 76069 tweets.
# Saved 76070 tweets.
# Saved 76071 tweets.
# Saved 76072 tweets.
# Saved 76073 tweets.
# Saved 76074 tweets.
# Saved 76075 tweets.
# Saved 76076 tweets.
# Saved 76077 tweets.
# Saved 76078 tweets.
# Saved 76079 tweets.
# Saved 76080 tweets.
# Saved 76081 tweets.
# Saved 76082 tweets.
# Saved 76083 tweets.
# Saved 76084 tweets.
# Saved 76085 tweets.
# Saved 76086 tweets.
# Saved 76087 tweets.
# Saved 76088 tweets.
# Saved 76089 tweets.
# Saved 76090 tweets.
# Saved 76091 tweets.
# Saved 76092 tweets.
# Saved 76093 tweets.
# Saved 76094 tweets.
# Saved 76095 tweets.
# Saved 76096 tweets.
# Saved 76097 tweets.
# Saved 76098 tweets.
# Saved 76099 tweets.
# Saved 76100 tweets.
# Saved 76102 tweets.
# Saved 76103 tweets.
# Saved 76104 tweets.
# Saved 76105 tweets.
# Saved 76106 tweets.
# Saved 76107 tweets.
# Saved 76108 tweets.
# Saved 76109 tweets.
# Saved 76110 tweets.
# Saved 76111 tweets.
# Saved 76112 tweets.
# Saved 76113 tweets.
# Saved 76114 tweets.
# Saved 76115 tweets.
# Saved 76116 tweets.
# Saved 76117 tweets.
# Saved 76118 tweets.
# Saved 76119 tweets.
# Saved 76120 tweets.
# Saved 76121 tweets.
# Saved 76122 tweets.
# Saved 76123 tweets.
# Saved 76124 tweets.
# Saved 76125 tweets.
# Saved 76126 tweets.
# Saved 76127 tweets.
# Saved 76128 tweets.
# Saved 76129 tweets.
# Saved 76130 tweets.
# Saved 76131 tweets.
# Saved 76132 tweets.
# Saved 76133 tweets.
# Saved 76134 tweets.
# Saved 76135 tweets.
# Saved 76136 tweets.
# Saved 76137 tweets.
# Saved 76138 tweets.
# Saved 76139 tweets.
# Saved 76140 tweets.
# Saved 76141 tweets.
# Saved 76142 tweets.
# Saved 76143 tweets.
# Saved 76144 tweets.
# Saved 76145 tweets.
# Saved 76146 tweets.
# Saved 76147 tweets.
# Saved 76148 tweets.
# Saved 76149 tweets.
# Saved 76150 tweets.
# Saved 76151 tweets.
# Saved 76152 tweets.
# Saved 76153 tweets.
# Saved 76154 tweets.
# Saved 76155 tweets.
# Saved 76156 tweets.
# Saved 76157 tweets.
# Saved 76158 tweets.
# Saved 76159 tweets.
# Saved 76160 tweets.
# Saved 76161 tweets.
# Saved 76162 tweets.
# Saved 76163 tweets.
# Saved 76164 tweets.
# Saved 76165 tweets.
# Saved 76166 tweets.
# Saved 76167 tweets.
# Saved 76168 tweets.
# Saved 76169 tweets.
# Saved 76170 tweets.
# Saved 76171 tweets.
# Saved 76172 tweets.
# Saved 76173 tweets.
# Saved 76174 tweets.
# Saved 76175 tweets.
# Saved 76176 tweets.
# Saved 76177 tweets.
# Saved 76178 tweets.
# Saved 76179 tweets.
# Saved 76180 tweets.
# Saved 76181 tweets.
# Saved 76182 tweets.
# Saved 76183 tweets.
# Saved 76184 tweets.
# Saved 76185 tweets.
# Saved 76186 tweets.
# Saved 76187 tweets.
# Saved 76188 tweets.
# Saved 76189 tweets.
# Saved 76190 tweets.
# Saved 76191 tweets.
# Saved 76192 tweets.
# Saved 76193 tweets.
# Saved 76194 tweets.
# Saved 76195 tweets.
# Saved 76196 tweets.
# Saved 76197 tweets.
# Saved 76198 tweets.
# Saved 76199 tweets.
# Saved 76200 tweets.
# Saved 76202 tweets.
# Saved 76203 tweets.
# Saved 76204 tweets.
# Saved 76205 tweets.
# Saved 76206 tweets.
# Saved 76207 tweets.
# Saved 76208 tweets.
# Saved 76209 tweets.
# Saved 76210 tweets.
# Saved 76211 tweets.
# Saved 76212 tweets.
# Saved 76213 tweets.
# Saved 76214 tweets.
# Saved 76215 tweets.
# Saved 76216 tweets.
# Saved 76217 tweets.
# Saved 76218 tweets.
# Saved 76219 tweets.
# Saved 76220 tweets.
# Saved 76221 tweets.
# Saved 76222 tweets.
# Saved 76223 tweets.
# Saved 76224 tweets.
# Saved 76225 tweets.
# Saved 76226 tweets.
# Saved 76227 tweets.
# Saved 76228 tweets.
# Saved 76229 tweets.
# Saved 76230 tweets.
# Saved 76231 tweets.
# Saved 76232 tweets.
# Saved 76233 tweets.
# Saved 76234 tweets.
# Saved 76235 tweets.
# Saved 76236 tweets.
# Saved 76237 tweets.
# Saved 76238 tweets.
# Saved 76239 tweets.
# Saved 76240 tweets.
# Saved 76241 tweets.
# Saved 76242 tweets.
# Saved 76243 tweets.
# Saved 76244 tweets.
# Saved 76245 tweets.
# Saved 76246 tweets.
# Saved 76247 tweets.
# Saved 76248 tweets.
# Saved 76249 tweets.
# Saved 76250 tweets.
# Saved 76251 tweets.
# Saved 76252 tweets.
# Saved 76253 tweets.
# Saved 76254 tweets.
# Saved 76255 tweets.
# Saved 76256 tweets.
# Saved 76257 tweets.
# Saved 76258 tweets.
# Saved 76259 tweets.
# Saved 76260 tweets.
# Saved 76261 tweets.
# Saved 76262 tweets.
# Saved 76263 tweets.
# Saved 76264 tweets.
# Saved 76265 tweets.
# Saved 76266 tweets.
# Saved 76267 tweets.
# Saved 76268 tweets.
# Saved 76269 tweets.
# Saved 76270 tweets.
# Saved 76271 tweets.
# Saved 76272 tweets.
# Saved 76273 tweets.
# Saved 76274 tweets.
# Saved 76275 tweets.
# Saved 76276 tweets.
# Saved 76277 tweets.
# Saved 76278 tweets.
# Saved 76279 tweets.
# Saved 76280 tweets.
# Saved 76281 tweets.
# Saved 76282 tweets.
# Saved 76283 tweets.
# Saved 76284 tweets.
# Saved 76285 tweets.
# Saved 76286 tweets.
# Saved 76287 tweets.
# Saved 76288 tweets.
# Saved 76289 tweets.
# Saved 76290 tweets.
# Saved 76291 tweets.
# Saved 76292 tweets.
# Saved 76293 tweets.
# Saved 76294 tweets.
# Saved 76295 tweets.
# Saved 76296 tweets.
# Saved 76297 tweets.
# Saved 76298 tweets.
# Saved 76299 tweets.
# Saved 76300 tweets.
# Saved 76302 tweets.
# Saved 76303 tweets.
# Saved 76304 tweets.
# Saved 76305 tweets.
# Saved 76306 tweets.
# Saved 76307 tweets.
# Saved 76308 tweets.
# Saved 76309 tweets.
# Saved 76310 tweets.
# Saved 76311 tweets.
# Saved 76312 tweets.
# Saved 76313 tweets.
# Saved 76314 tweets.
# Saved 76315 tweets.
# Saved 76316 tweets.
# Saved 76317 tweets.
# Saved 76318 tweets.
# Saved 76319 tweets.
# Saved 76320 tweets.
# Saved 76321 tweets.
# Saved 76322 tweets.
# Saved 76323 tweets.
# Saved 76324 tweets.
# Saved 76325 tweets.
# Saved 76326 tweets.
# Saved 76327 tweets.
# Saved 76328 tweets.
# Saved 76329 tweets.
# Saved 76330 tweets.
# Saved 76331 tweets.
# Saved 76332 tweets.
# Saved 76333 tweets.
# Saved 76334 tweets.
# Saved 76335 tweets.
# Saved 76336 tweets.
# Saved 76337 tweets.
# Saved 76338 tweets.
# Saved 76339 tweets.
# Saved 76340 tweets.
# Saved 76341 tweets.
# Saved 76342 tweets.
# Saved 76343 tweets.
# Saved 76344 tweets.
# Saved 76345 tweets.
# Saved 76346 tweets.
# Saved 76347 tweets.
# Saved 76348 tweets.
# Saved 76349 tweets.
# Saved 76350 tweets.
# Saved 76351 tweets.
# Saved 76352 tweets.
# Saved 76353 tweets.
# Saved 76354 tweets.
# Saved 76355 tweets.
# Saved 76356 tweets.
# Saved 76357 tweets.
# Saved 76358 tweets.
# Saved 76359 tweets.
# Saved 76360 tweets.
# Saved 76361 tweets.
# Saved 76362 tweets.
# Saved 76363 tweets.
# Saved 76364 tweets.
# Saved 76365 tweets.
# Saved 76366 tweets.
# Saved 76367 tweets.
# Saved 76368 tweets.
# Saved 76369 tweets.
# Saved 76370 tweets.
# Saved 76371 tweets.
# Saved 76372 tweets.
# Saved 76373 tweets.
# Saved 76374 tweets.
# Saved 76375 tweets.
# Saved 76376 tweets.
# Saved 76377 tweets.
# Saved 76378 tweets.
# Saved 76379 tweets.
# Saved 76380 tweets.
# Saved 76381 tweets.
# Saved 76382 tweets.
# Saved 76383 tweets.
# Saved 76384 tweets.
# Saved 76385 tweets.
# Saved 76386 tweets.
# Saved 76387 tweets.
# Saved 76388 tweets.
# Saved 76389 tweets.
# Saved 76390 tweets.
# Saved 76391 tweets.
# Saved 76392 tweets.
# Saved 76393 tweets.
# Saved 76394 tweets.
# Saved 76395 tweets.
# Saved 76396 tweets.
# Saved 76397 tweets.
# Saved 76398 tweets.
# Saved 76399 tweets.
# Saved 76400 tweets.
# Saved 76402 tweets.
# Saved 76403 tweets.
# Saved 76404 tweets.
# Saved 76405 tweets.
# Saved 76406 tweets.
# Saved 76407 tweets.
# Saved 76408 tweets.
# Saved 76409 tweets.
# Saved 76410 tweets.
# Saved 76411 tweets.
# Saved 76412 tweets.
# Saved 76413 tweets.
# Saved 76414 tweets.
# Saved 76415 tweets.
# Saved 76416 tweets.
# Saved 76417 tweets.
# Saved 76418 tweets.
# Saved 76419 tweets.
# Saved 76420 tweets.
# Saved 76421 tweets.
# Saved 76422 tweets.
# Saved 76423 tweets.
# Saved 76424 tweets.
# Saved 76425 tweets.
# Saved 76426 tweets.
# Saved 76427 tweets.
# Saved 76428 tweets.
# Saved 76429 tweets.
# Saved 76430 tweets.
# Saved 76431 tweets.
# Saved 76432 tweets.
# Saved 76433 tweets.
# Saved 76434 tweets.
# Saved 76435 tweets.
# Saved 76436 tweets.
# Saved 76437 tweets.
# Saved 76438 tweets.
# Saved 76439 tweets.
# Saved 76440 tweets.
# Saved 76441 tweets.
# Saved 76442 tweets.
# Saved 76443 tweets.
# Saved 76444 tweets.
# Saved 76445 tweets.
# Saved 76446 tweets.
# Saved 76447 tweets.
# Saved 76448 tweets.
# Saved 76449 tweets.
# Saved 76450 tweets.
# Saved 76451 tweets.
# Saved 76452 tweets.
# Saved 76453 tweets.
# Saved 76454 tweets.
# Saved 76455 tweets.
# Saved 76456 tweets.
# Saved 76457 tweets.
# Saved 76458 tweets.
# Saved 76459 tweets.
# Saved 76460 tweets.
# Saved 76461 tweets.
# Saved 76462 tweets.
# Saved 76463 tweets.
# Saved 76464 tweets.
# Saved 76465 tweets.
# Saved 76466 tweets.
# Saved 76467 tweets.
# Saved 76468 tweets.
# Saved 76469 tweets.
# Saved 76470 tweets.
# Saved 76471 tweets.
# Saved 76472 tweets.
# Saved 76473 tweets.
# Saved 76474 tweets.
# Saved 76475 tweets.
# Saved 76476 tweets.
# Saved 76477 tweets.
# Saved 76478 tweets.
# Saved 76479 tweets.
# Saved 76480 tweets.
# Saved 76481 tweets.
# Saved 76482 tweets.
# Saved 76483 tweets.
# Saved 76484 tweets.
# Saved 76485 tweets.
# Saved 76486 tweets.
# Saved 76487 tweets.
# Saved 76488 tweets.
# Saved 76489 tweets.
# Saved 76490 tweets.
# Saved 76491 tweets.
# Saved 76492 tweets.
# Saved 76493 tweets.
# Saved 76494 tweets.
# Saved 76495 tweets.
# Saved 76496 tweets.
# Saved 76497 tweets.
# Saved 76498 tweets.
# Saved 76499 tweets.
# Saved 76500 tweets.
# Saved 76502 tweets.
# Saved 76503 tweets.
# Saved 76504 tweets.
# Saved 76505 tweets.
# Saved 76506 tweets.
# Saved 76507 tweets.
# Saved 76508 tweets.
# Saved 76509 tweets.
# Saved 76510 tweets.
# Saved 76511 tweets.
# Saved 76512 tweets.
# Saved 76513 tweets.
# Saved 76514 tweets.
# Saved 76515 tweets.
# Saved 76516 tweets.
# Saved 76517 tweets.
# Saved 76518 tweets.
# Saved 76519 tweets.
# Saved 76520 tweets.
# Saved 76521 tweets.
# Saved 76522 tweets.
# Saved 76523 tweets.
# Saved 76524 tweets.
# Saved 76525 tweets.
# Saved 76526 tweets.
# Saved 76527 tweets.
# Saved 76528 tweets.
# Saved 76529 tweets.
# Saved 76530 tweets.
# Saved 76531 tweets.
# Saved 76532 tweets.
# Saved 76533 tweets.
# Saved 76534 tweets.
# Saved 76535 tweets.
# Saved 76536 tweets.
# Saved 76537 tweets.
# Saved 76538 tweets.
# Saved 76539 tweets.
# Saved 76540 tweets.
# Saved 76541 tweets.
# Saved 76542 tweets.
# Saved 76543 tweets.
# Saved 76544 tweets.
# Saved 76545 tweets.
# Saved 76546 tweets.
# Saved 76547 tweets.
# Saved 76548 tweets.
# Saved 76549 tweets.
# Saved 76550 tweets.
# Saved 76551 tweets.
# Saved 76552 tweets.
# Saved 76553 tweets.
# Saved 76554 tweets.
# Saved 76555 tweets.
# Saved 76556 tweets.
# Saved 76557 tweets.
# Saved 76558 tweets.
# Saved 76559 tweets.
# Saved 76560 tweets.
# Saved 76561 tweets.
# Saved 76562 tweets.
# Saved 76563 tweets.
# Saved 76564 tweets.
# Saved 76565 tweets.
# Saved 76566 tweets.
# Saved 76567 tweets.
# Saved 76568 tweets.
# Saved 76569 tweets.
# Saved 76570 tweets.
# Saved 76571 tweets.
# Saved 76572 tweets.
# Saved 76573 tweets.
# Saved 76574 tweets.
# Saved 76575 tweets.
# Saved 76576 tweets.
# Saved 76577 tweets.
# Saved 76578 tweets.
# Saved 76579 tweets.
# Saved 76580 tweets.
# Saved 76581 tweets.
# Saved 76582 tweets.
# Saved 76583 tweets.
# Saved 76584 tweets.
# Saved 76585 tweets.
# Saved 76586 tweets.
# Saved 76587 tweets.
# Saved 76588 tweets.
# Saved 76589 tweets.
# Saved 76590 tweets.
# Saved 76591 tweets.
# Saved 76592 tweets.
# Saved 76593 tweets.
# Saved 76594 tweets.
# Saved 76595 tweets.
# Saved 76596 tweets.
# Saved 76597 tweets.
# Saved 76598 tweets.
# Saved 76599 tweets.
# Saved 76600 tweets.
# Saved 76602 tweets.
# Saved 76603 tweets.
# Saved 76604 tweets.
# Saved 76605 tweets.
# Saved 76606 tweets.
# Saved 76607 tweets.
# Saved 76608 tweets.
# Saved 76609 tweets.
# Saved 76610 tweets.
# Saved 76611 tweets.
# Saved 76612 tweets.
# Saved 76613 tweets.
# Saved 76614 tweets.
# Saved 76615 tweets.
# Saved 76616 tweets.
# Saved 76617 tweets.
# Saved 76618 tweets.
# Saved 76619 tweets.
# Saved 76620 tweets.
# Saved 76621 tweets.
# Saved 76622 tweets.
# Saved 76623 tweets.
# Saved 76624 tweets.
# Saved 76625 tweets.
# Saved 76626 tweets.
# Saved 76627 tweets.
# Saved 76628 tweets.
# Saved 76629 tweets.
# Saved 76630 tweets.
# Saved 76631 tweets.
# Saved 76632 tweets.
# Saved 76633 tweets.
# Saved 76634 tweets.
# Saved 76635 tweets.
# Saved 76636 tweets.
# Saved 76637 tweets.
# Saved 76638 tweets.
# Saved 76639 tweets.
# Saved 76640 tweets.
# Saved 76641 tweets.
# Saved 76642 tweets.
# Saved 76643 tweets.
# Saved 76644 tweets.
# Saved 76645 tweets.
# Saved 76646 tweets.
# Saved 76647 tweets.
# Saved 76648 tweets.
# Saved 76649 tweets.
# Saved 76650 tweets.
# Saved 76651 tweets.
# Saved 76652 tweets.
# Saved 76653 tweets.
# Saved 76654 tweets.
# Saved 76655 tweets.
# Saved 76656 tweets.
# Saved 76657 tweets.
# Saved 76658 tweets.
# Saved 76659 tweets.
# Saved 76660 tweets.
# Saved 76661 tweets.
# Saved 76662 tweets.
# Saved 76663 tweets.
# Saved 76664 tweets.
# Saved 76665 tweets.
# Saved 76666 tweets.
# Saved 76667 tweets.
# Saved 76668 tweets.
# Saved 76669 tweets.
# Saved 76670 tweets.
# Saved 76671 tweets.
# Saved 76672 tweets.
# Saved 76673 tweets.
# Saved 76674 tweets.
# Saved 76675 tweets.
# Saved 76676 tweets.
# Saved 76677 tweets.
# Saved 76678 tweets.
# Saved 76679 tweets.
# Saved 76680 tweets.
# Saved 76681 tweets.
# Saved 76682 tweets.
# Saved 76683 tweets.
# Saved 76684 tweets.
# Saved 76685 tweets.
# Saved 76686 tweets.
# Saved 76687 tweets.
# Saved 76688 tweets.
# Saved 76689 tweets.
# Saved 76690 tweets.
# Saved 76691 tweets.
# Saved 76692 tweets.
# Saved 76693 tweets.
# Saved 76694 tweets.
# Saved 76695 tweets.
# Saved 76696 tweets.
# Saved 76697 tweets.
# Saved 76698 tweets.
# Saved 76699 tweets.
# Saved 76700 tweets.
# Saved 76702 tweets.
# Saved 76703 tweets.
# Saved 76704 tweets.
# Saved 76705 tweets.
# Saved 76706 tweets.
# Saved 76707 tweets.
# Saved 76708 tweets.
# Saved 76709 tweets.
# Saved 76710 tweets.
# Saved 76711 tweets.
# Saved 76712 tweets.
# Saved 76713 tweets.
# Saved 76714 tweets.
# Saved 76715 tweets.
# Saved 76716 tweets.
# Saved 76717 tweets.
# Saved 76718 tweets.
# Saved 76719 tweets.
# Saved 76720 tweets.
# Saved 76721 tweets.
# Saved 76722 tweets.
# Saved 76723 tweets.
# Saved 76724 tweets.
# Saved 76725 tweets.
# Saved 76726 tweets.
# Saved 76727 tweets.
# Saved 76728 tweets.
# Saved 76729 tweets.
# Saved 76730 tweets.
# Saved 76731 tweets.
# Saved 76732 tweets.
# Saved 76733 tweets.
# Saved 76734 tweets.
# Saved 76735 tweets.
# Saved 76736 tweets.
# Saved 76737 tweets.
# Saved 76738 tweets.
# Saved 76739 tweets.
# Saved 76740 tweets.
# Saved 76741 tweets.
# Saved 76742 tweets.
# Saved 76743 tweets.
# Saved 76744 tweets.
# Saved 76745 tweets.
# Saved 76746 tweets.
# Saved 76747 tweets.
# Saved 76748 tweets.
# Saved 76749 tweets.
# Saved 76750 tweets.
# Saved 76751 tweets.
# Saved 76752 tweets.
# Saved 76753 tweets.
# Saved 76754 tweets.
# Saved 76755 tweets.
# Saved 76756 tweets.
# Saved 76757 tweets.
# Saved 76758 tweets.
# Saved 76759 tweets.
# Saved 76760 tweets.
# Saved 76761 tweets.
# Saved 76762 tweets.
# Saved 76763 tweets.
# Saved 76764 tweets.
# Saved 76765 tweets.
# Saved 76766 tweets.
# Saved 76767 tweets.
# Saved 76768 tweets.
# Saved 76769 tweets.
# Saved 76770 tweets.
# Saved 76771 tweets.
# Saved 76772 tweets.
# Saved 76773 tweets.
# Saved 76774 tweets.
# Saved 76775 tweets.
# Saved 76776 tweets.
# Saved 76777 tweets.
# Saved 76778 tweets.
# Saved 76779 tweets.
# Saved 76780 tweets.
# Saved 76781 tweets.
# Saved 76782 tweets.
# Saved 76783 tweets.
# Saved 76784 tweets.
# Saved 76785 tweets.
# Saved 76786 tweets.
# Saved 76787 tweets.
# Saved 76788 tweets.
# Saved 76789 tweets.
# Saved 76790 tweets.
# Saved 76791 tweets.
# Saved 76792 tweets.
# Saved 76793 tweets.
# Saved 76794 tweets.
# Saved 76795 tweets.
# Saved 76796 tweets.
# Saved 76797 tweets.
# Saved 76798 tweets.
# Saved 76799 tweets.
# Saved 76800 tweets.
# Saved 76802 tweets.
# Saved 76803 tweets.
# Saved 76804 tweets.
# Saved 76805 tweets.
# Saved 76806 tweets.
# Saved 76807 tweets.
# Saved 76808 tweets.
# Saved 76809 tweets.
# Saved 76810 tweets.

# %% [markdown]
# #### Selecting using search

# %%
#auth = tweepy.0AuthHandler(consumer_key, consumer_secret) #two arguments
#auth.set_access_token(access_token, access_token_secret)

auth = OAuthHandler(anfalkeys.CONSUMER_KEY, anfalkeys.CONSUMER_SECRET)
auth.set_access_token(anfalkeys.TOKEN_KEY, anfalkeys.TOKEN_SECRET)
    return auth
    
    

api = tweepy.API(auth)

#collect tweets with certain key words
public_tweets = api.search('Trump')

#print all out "increment every value in a list"
for tweet in public_tweets:
    print (tweet.text)
    analysis = TextBlob(tweet.text)
    print (analysis.sentiment)
    print("")

# %%
class TwitterClient(object):
    def__init__(self,query, retweets_only = False, with_sentiment = False):
        r = final.authenticate("anfalkey.json")
        self.query = query
        self.retweets_only = retweets_only
        self.with_sentiment = with_sentiment 
        self.api = tweetpy.APU (self.auth)
        self.tweet_count_max = 1000 #prevent rate limiting
    except:
        print ("error: authentication failed")
        
def set_query(self, query=''):
        self.query = query
def set_retweet_checking(self, retweets_only='false'):
        self.retweets_only = retweets_only
def set_with_sentiment(self, with_sentiment='false'):
        self.with_sentiment = with_sentiment
def clean_tweet(self, tweet):
    return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)", " ", tweet).split())

#geting sentiments for each tweet between -1 to 1
def get_tweet_sentiment(self, tweet):
    analysis = TextBlob(self.clean_tweet(tweet))
    if analysis.sentiment.polarity > 0:
        return 'positive'
    elif analysis.sentiment.polarity == 0:
        return 'neutral'
    else:
        return 'negative'
    
#get tweets
def get_tweets(self):
    tweets = []
    
     try:
        recd_tweets = self.api.search(q=self.query,
                                          count=self.tweet_count_max)
        if not recd_tweets:
            pass
        for tweet in recd_tweets:
            parsed_tweet = {}

        parsed_tweet['text'] = tweet.text
        parsed_tweet['user'] = tweet.user.screen_name
                
        if self.with_sentiment == 1:
             parsed_tweet['sentiment'] = self.get_tweet_sentiment(tweet.text)
        else:
             parsed_tweet['sentiment'] = 'unavailable'

        if tweet.retweet_count > 0 and self.retweets_only == 1:
            if parsed_tweet not in tweets:
                tweets.append(parsed_tweet)
        elif not self.retweets_only:
            if parsed_tweet not in tweets:
                tweets.append(parsed_tweet)
        return tweets
    
    except tweety.TweetError as e:
        print ("error:" + str(e))

# %%
from tweepy import API 
from tweepy import Cursor
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream

from textblob import TextBlob
 
import anfalkey.json

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import re


class TwitterAnalysis():
    def__init__(self,twitter_user=None, query, retweets_only = False, with_sentiment = False):
       
        self.query = query
        self.retweets_only = retweets_only
        self.with_sentiment = with_sentiment 
        self.api = tweetpy.APU (self.auth)
        self.tweet_count_max = 1000 #prevent rate limiting
    except:
        print ("error: authentication failed")
        
def set_query(self, query=''):
        self.query = query
def set_retweet_checking(self, retweets_only='false'):
        self.retweets_only = retweets_only
def set_with_sentiment(self, with_sentiment='false'):
        self.with_sentiment = with_sentiment
def clean_tweet(self, tweet):
    return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)", " ", tweet).split())

#geting sentiments for each tweet between -1 to 1
def get_tweet_sentiment(self, tweet):
    analysis = TextBlob(self.clean_tweet(tweet))
    if analysis.sentiment.polarity > 0:
        return 'positive'
    elif analysis.sentiment.polarity == 0:
        return 'neutral'
    else:
        return 'negative'
    
#get tweets
def get_tweets(self):
    tweets = []
    
     try:
        recd_tweets = self.api.search(q=self.query,
                                          count=self.tweet_count_max)
        if not recd_tweets:
            pass
        for tweet in recd_tweets:
            parsed_tweet = {}

        parsed_tweet['text'] = tweet.text
        parsed_tweet['user'] = tweet.user.screen_name
                
        if self.with_sentiment == 1:
             parsed_tweet['sentiment'] = self.get_tweet_sentiment(tweet.text)
        else:
             parsed_tweet['sentiment'] = 'unavailable'

        if tweet.retweet_count > 0 and self.retweets_only == 1:
            if parsed_tweet not in tweets:
                tweets.append(parsed_tweet)
        elif not self.retweets_only:
            if parsed_tweet not in tweets:
                tweets.append(parsed_tweet)
        return tweets
    
    except tweety.TweetError as e:
        print ("error:" + str(e))

# %% [markdown]
# #### Streaming Live Tweets

# %%
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream

#credentianls
import anfalkeys

#class for streaming & processing live tweets
class TwitterStreamer ():
    
    def stream_tweets (self, fetched_tweets_filename, hash_tag_list):
        # This handles twittter authentication & the connection to the twitter streaming api
         listener = StdOutListener()
        auth = OAuthHandler(anfalkeys.CONSUMER_KEY, anfalkeys.CONSUMER_SECRET)
        auth.set_access_token(anfalkeys.TOKEN_KEY, anfalkeys.TOKEN_SECRET)

        stream = Stream(auth, listener)
    
        #focused on some keywords of hashtags
        #stream.filter(track=['donald trump', 'hillary clinton', 'barack obama', 'bernie sanders'])
        stream.filter(track=hash_tag_list)


#basic listener class that just prints recieved tweets to stdout       
class StdOutListener(StreamListener):
    def __init__ (self,fetched_tweets_filename):
        self.fetched_tweets_filename = fetched_tweets_filename
    
    def on_data(self,data): #take data that is streamed in from the stream listener so the one that's listening for tweets
        try:
            print(data)
            with open(self.fetched_tweets_filename, 'a') as tf:
                tf.write(data)
            return True
        except BaseException as e:
            print("error on data: %s" %str(e))
        return True
 
    
    def on_error(self, data): #overwriting & print the status methos 
        print(status)
        
if __name__ == "__main__":
    hash_tag_list = ["donald trump", "Kylie jenner"]
    fetched_tweets_filename = "hashtag_tweets.json"
    
    #twitter streaming object
    twitter_streamer = TwitterStreamer()
    twitter_streamer.stream_tweets(fetched_tweets_filename, hash_tag_list)

# %% [markdown]
# #### Cursor and Pagination

# %%
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream

from tweepy import API
from tweepy import Cursor 

#credentianls
import anfalkeys

#twitter client
class TwitterClient():
    def __init__(self, twitter_user = None):
        self.auth = Authentication().authenticate_twitter_app()
        self.twitter_client = API(self.auth)
        
        self.twitter_user = twitter_user

    #funtion to get tweets
    def get_user_timeline_tweets(self, num_tweets):
        tweets =[]
        for tweet in Cursor(self.twitter_client.user_timeline, id=self.twitter_user).items(num_tweets):
            tweets.append(tweet)
        return tweets
    
    
    def get_friend_list(self, num_friends):
        friend_list=[]
        for friend in Cursor(self.twitter_client.friends, id= self.twitter_user).items(num_friends):
            friend_list.append(friends)
        return friend_list
    
    def get_home_timeline_tweets(self, num_tweets):
        home_timeline_tweets =[]
        for tweet in Cursor (self.twitter_client.home_timeline, id=self.twitter_user).items(num_tweets):
            home_timeline_tweets.append(tweet)
        return home_timeline_tweets
    
    
#authentication class
class Authentication():
    def authenticate_twitter_app(self):
        auth = OAuthHandler(anfalkeys.CONSUMER_KEY, anfalkeys.CONSUMER_SECRET)
        auth.set_access_token(anfalkeys.TOKEN_KEY, anfalkeys.TOKEN_SECRET)
        return auth
    
    
#class for streaming & processing live tweets
class TwitterStreamer ():
    def __init__(self):
        self.twitter_authenticator = Authentication()
    
    
    def stream_tweets (self, fetched_tweets_filename, hash_tag_list):
        # This handles twittter authentication & the connection to the twitter streaming api
        listener = TwitterLis(fetched_tweets_filename)
        auth = self.twitter_authenticator.authenticate_twitter_app()
        stream = Stream(auth, listener)
    
        #focused on some keywords of hashtags
        #stream.filter(track=['donald trump', 'hillary clinton', 'barack obama', 'bernie sanders'])
        stream.filter(track=hash_tag_list)


#printing tweets & writing it into a file
class TwitterLis(StreamListener):
    def __init__ (self,fetched_tweets_filename):
        self.fetched_tweets_filename = fetched_tweets_filename
    
    def on_data(self,data): #take data that is streamed in from the stream listener so the one that's listening for tweets
        try:
            print(data)
            with open(self.fetched_tweets_filename, 'a') as tf:
                tf.write(data)
            return True
        except BaseException as e:
            print("error on data: %s" %str(e))
        return True
 
    
    def on_error(self, status): #overwriting & print the status methos 
        if status == 420:
            return False #kill connection -return false data method in case rate limit occurs
        print(status)
        
if __name__ == "__main__":
    hash_tag_list = ["Donald Trump", "Kylie jenner"]
    fetched_tweets_filename = "hashtag_tweets.json"
    
    
    twitter_client = TwitterClient('pycon')
    print(twitter_client.get_user_timeline_tweets(1))
    #twitter streaming object
   # twitter_streamer = TwitterStreamer()
   # twitter_streamer.stream_tweets(fetched_tweets_filename, hash_tag_list)
# Out:
# [Status(_api=<tweepy.api.API object at 0x00000249C7F19DA0>, _json={'created_at': 'Thu Oct 10 16:19:40 +0000 2019', 'id': 1182329864541671425, 'id_str': '1182329864541671425', 'text': 'Considering proposing a hatchery event for PyCon US 2020? Call for proposals has opened, find out more details on… https://t.co/q4Y16beUKm', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/q4Y16beUKm', 'expanded_url': 'https://twitter.com/i/web/status/1182329864541671425', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [115, 138]}]}, 'source': '<a href="https://sproutsocial.com" rel="nofollow">Sprout Social</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 9475182, 'id_str': '9475182', 'name': 'PyCon', 'screen_name': 'pycon', 'location': 'Pittsburgh, PA', 'description': 'PyCon is coming to Pittsburgh, PA on April 15-23, 2020.', 'url': 'https://t.co/cDA7VmP4hV', 'entities': {'url': {'urls': [{'url': 'https://t.co/cDA7VmP4hV', 'expanded_url': 'http://us.pycon.org', 'display_url': 'us.pycon.org', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 46501, 'friends_count': 5, 'listed_count': 1010, 'created_at': 'Tue Oct 16 11:17:41 +0000 2007', 'favourites_count': 1092, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 3927, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '131516', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif', 'profile_background_tile': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1155940716977299456/r2vfBzT1_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1155940716977299456/r2vfBzT1_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/9475182/1566316758', 'profile_link_color': '009CBD', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': False, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 10, 'favorite_count': 20, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'en'}, created_at=datetime.datetime(2019, 10, 10, 16, 19, 40), id=1182329864541671425, id_str='1182329864541671425', text='Considering proposing a hatchery event for PyCon US 2020? Call for proposals has opened, find out more details on… https://t.co/q4Y16beUKm', truncated=True, entities={'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/q4Y16beUKm', 'expanded_url': 'https://twitter.com/i/web/status/1182329864541671425', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [115, 138]}]}, source='Sprout Social', source_url='https://sproutsocial.com', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, author=User(_api=<tweepy.api.API object at 0x00000249C7F19DA0>, _json={'id': 9475182, 'id_str': '9475182', 'name': 'PyCon', 'screen_name': 'pycon', 'location': 'Pittsburgh, PA', 'description': 'PyCon is coming to Pittsburgh, PA on April 15-23, 2020.', 'url': 'https://t.co/cDA7VmP4hV', 'entities': {'url': {'urls': [{'url': 'https://t.co/cDA7VmP4hV', 'expanded_url': 'http://us.pycon.org', 'display_url': 'us.pycon.org', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': ...

# %% [markdown]
# #### Analyzing Tweet Data
# ##### take some tweets & analyze them using numpy and pandas

# %%
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream

from tweepy import API
from tweepy import Cursor 

import numpy as np
import pandas as pd

#credentianls
import anfalkeys

#twitter client
class TwitterClient():
    def __init__(self, twitter_user = None):
        self.auth = Authentication().authenticate_twitter_app()
        self.twitter_client = API(self.auth)
        
        self.twitter_user = twitter_user
        
    def get_twitter_client_api(self):
        return self.twitter_client

    #funtion to get tweets
    def get_user_timeline_tweets(self, num_tweets):
        tweets =[]
        for tweet in Cursor(self.twitter_client.user_timeline, id=self.twitter_user).items(num_tweets):
            tweets.append(tweet)
        return tweets
    
    
    def get_friend_list(self, num_friends):
        friend_list=[]
        for friend in Cursor(self.twitter_client.friends, id= self.twitter_user).items(num_friends):
            friend_list.append(friends)
        return friend_list
    
    def get_home_timeline_tweets(self, num_tweets):
        home_timeline_tweets =[]
        for tweet in Cursor (self.twitter_client.home_timeline, id=self.twitter_user).items(num_tweets):
            home_timeline_tweets.append(tweet)
        return home_timeline_tweets
    
    
#authentication class
class Authentication():
    def authenticate_twitter_app(self):
        auth = OAuthHandler(anfalkeys.CONSUMER_KEY, anfalkeys.CONSUMER_SECRET)
        auth.set_access_token(anfalkeys.TOKEN_KEY, anfalkeys.TOKEN_SECRET)
        return auth
    
    
#class for streaming & processing live tweets
class TwitterStreamer ():
    def __init__(self):
        self.twitter_authenticator = Authentication()
    
    
    def stream_tweets (self, fetched_tweets_filename, hash_tag_list):
        # This handles twittter authentication & the connection to the twitter streaming api
        listener = TwitterLis(fetched_tweets_filename)
        auth = self.twitter_authenticator.authenticate_twitter_app()
        stream = Stream(auth, listener)
    
        #focused on some keywords of hashtags
        #stream.filter(track=['donald trump', 'hillary clinton', 'barack obama', 'bernie sanders'])
        stream.filter(track=hash_tag_list)


#printing tweets & writing it into a file
class TwitterLis(StreamListener):
    def __init__ (self,fetched_tweets_filename):
        self.fetched_tweets_filename = fetched_tweets_filename
    
    def on_data(self,data): #take data that is streamed in from the stream listener so the one that's listening for tweets
        try:
            print(data)
            with open(self.fetched_tweets_filename, 'a') as tf:
                tf.write(data)
            return True
        except BaseException as e:
            print("error on data: %s" %str(e))
        return True
 
    
    def on_error(self, status): #overwriting & print the status methos 
        if status == 420:
            return False #kill connection -return false data method in case rate limit occurs
        print(status)
        
#class responsible for analyzing and categorizing tweets
class TweetAnalyzer():
    def tweets_to_data_frame(self, tweets):
        #we are creating a list and looping thro' every single tweet and extract text
        df = pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['Tweets']) #given by panda 
        
        #store id - numpy array - lopp through tweets to get id
        df['Id'] = np.array([tweet.id for tweet in tweets])
        df['Len'] = np.array([len(tweet.text) for tweet in tweets])
        df['Date'] = np.array([tweet.created_at for tweet in tweets])
        df['Source'] = np.array([tweet.source for tweet in tweets])
        df['Num of Likes'] = np.array([tweet.favorite_count for tweet in tweets])
        df['Num of Retweets'] = np.array([tweet.retweet_count for tweet in tweets])
        return df
        
if __name__ == "__main__":
    twitter_client = TwitterClient()
    tweet_analyzer = TweetAnalyzer()
    api = twitter_client.get_twitter_client_api()
    
    tweets = api.user_timeline(screen_name = "KylieJenner", count=10)
    
    #print (dir(tweets[0]))
    #print(tweets[0].id)
    #print (tweets[0].retweet_count)
    df = tweet_analyzer.tweets_to_data_frame(tweets)
    print(df.head(10))
# Out:
#                                               Tweets                   Id  \
# 0    https://t.co/uXabNn5vNL https://t.co/zAMkzbEUTS  1185001551133196288
# 1    https://t.co/uXabNn5vNL https://t.co/IUtZSqjElE  1185001520355368960
# 2          daddy’s girls 🙄🙄😍 https://t.co/Tdh69HgRFe  1184915267773583361
# 3             I’m doneeeeeee https://t.co/060Z3krDvj  1184890222657409024
# 4                     💀💀💀🤣🤣🤣 https://t.co/gUMmkiEa58  1184886015896342528
# 5  let the festivities begin 🧡 https://t.co/BSqTh...  1184574278626201600
# 6  Two of my all time favorite Lip Kits are on sa...  1184563469913190400
# 7                       💀💀💀💀 https://t.co/KR0T8n2uID  1184560926877310976
# 8  RT @kyliecosmetics: It’s #NationalBossDay and ...  1184543467554263040
# 9  my @kyliecosmetics @ultabeauty holiday collect...  1183391312436838400
#
#    Len                Date              Source  Num of Likes  Num of Retweets
# 0   47 2019-10-18 01:16:00     Twitter Web App         37753             4681
# 1   47 2019-10-18 01:15:53     Twitter Web App         15433             1653
# 2   41 2019-10-17 19:33:09     Twitter Web App        456580            68796
# 3   38 2019-10-17 17:53:37  Twitter for iPhone        488889            82476
# 4   30 2019-10-17 17:36:54  Twitter for iPhone        513063            83288
# 5   51 2019-10-16 20:58:11     Twitter Web App        221182            19278
# 6  140 2019-10-16 20:15:14     Twitter Web App          9706              416
# 7   28 2019-10-16 20:05:07  Twitter for iPhone        439676            57521
# 8  139 2019-10-16 18:55:45     Twitter Web App             0              293
# 9  131 2019-10-13 14:37:29  Twitter for iPhone          6512              345

# %% [markdown]
# #### Visualizing Tweet Data

# %%
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream

from tweepy import API
from tweepy import Cursor 

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

#credentianls
import anfalkeys

#twitter client
class TwitterClient():
    def __init__(self, twitter_user = None):
        self.auth = Authentication().authenticate_twitter_app()
        self.twitter_client = API(self.auth)
        
        self.twitter_user = twitter_user
        
    def get_twitter_client_api(self):
        return self.twitter_client

    #funtion to get tweets
    def get_user_timeline_tweets(self, num_tweets):
        tweets =[]
        for tweet in Cursor(self.twitter_client.user_timeline, id=self.twitter_user).items(num_tweets):
            tweets.append(tweet)
        return tweets
    
    
    def get_friend_list(self, num_friends):
        friend_list=[]
        for friend in Cursor(self.twitter_client.friends, id= self.twitter_user).items(num_friends):
            friend_list.append(friends)
        return friend_list
    
    def get_home_timeline_tweets(self, num_tweets):
        home_timeline_tweets =[]
        for tweet in Cursor (self.twitter_client.home_timeline, id=self.twitter_user).items(num_tweets):
            home_timeline_tweets.append(tweet)
        return home_timeline_tweets
    
    
#authentication class
class Authentication():
    def authenticate_twitter_app(self):
        auth = OAuthHandler(anfalkeys.CONSUMER_KEY, anfalkeys.CONSUMER_SECRET)
        auth.set_access_token(anfalkeys.TOKEN_KEY, anfalkeys.TOKEN_SECRET)
        return auth
    
    
#class for streaming & processing live tweets
class TwitterStreamer ():
    def __init__(self):
        self.twitter_authenticator = Authentication()
    
    
    def stream_tweets (self, fetched_tweets_filename, hash_tag_list):
        # This handles twittter authentication & the connection to the twitter streaming api
        listener = TwitterLis(fetched_tweets_filename)
        auth = self.twitter_authenticator.authenticate_twitter_app()
        stream = Stream(auth, listener)
    
        #focused on some keywords of hashtags
        #stream.filter(track=['donald trump', 'hillary clinton', 'barack obama', 'bernie sanders'])
        stream.filter(track=hash_tag_list)


#printing tweets & writing it into a file
class TwitterLis(StreamListener):
    def __init__ (self,fetched_tweets_filename):
        self.fetched_tweets_filename = fetched_tweets_filename
    
    def on_data(self,data): #take data that is streamed in from the stream listener so the one that's listening for tweets
        try:
            print(data)
            with open(self.fetched_tweets_filename, 'a') as tf:
                tf.write(data)
            return True
        except BaseException as e:
            print("error on data: %s" %str(e))
        return True
 
    
    def on_error(self, status): #overwriting & print the status methos 
        if status == 420:
            return False #kill connection -return false data method in case rate limit occurs
        print(status)
        
#class responsible for analyzing and categorizing tweets
class TweetAnalyzer():
    def tweets_to_data_frame(self, tweets):
        #we are creating a list and looping thro' every single tweet and extract text
        df = pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['Tweets']) #given by panda 
        
        #store id - numpy array - lopp through tweets to get id
        df['ID'] = np.array([tweet.id for tweet in tweets])
        df['Len'] = np.array([len(tweet.text) for tweet in tweets])
        df['Date'] = np.array([tweet.created_at for tweet in tweets])
        df['Source'] = np.array([tweet.source for tweet in tweets])
        df['Num of Likes'] = np.array([tweet.favorite_count for tweet in tweets])
        df['Num of Retweets'] = np.array([tweet.retweet_count for tweet in tweets])
        return df
        
if __name__ == "__main__":
    twitter_client = TwitterClient()
    tweet_analyzer = TweetAnalyzer()
    
    api = twitter_client.get_twitter_client_api()
    
    tweets = api.user_timeline(screen_name = "KylieJenner", count=200)

    df = tweet_analyzer.tweets_to_data_frame(tweets)
    
    #avg length of all the tweets
    print(np.mean(df['Len']))
    
    #tweets with most likes
    print(np.max(df['Num of Likes']))
    
    #number of retweets
    print (np.max(df['Num of Retweets']))
    
    #time series to show the number of likes based on a given day
    #time_likes = pd.Series(data = df['Num of Likes'].values, index = df['Date'])
    #time_likes.plot(figsize =(16,4), color = 'pink')
    
    #time_retweets = pd.Series(data = df['Num of Retweets'].values, index = df['Date'])
    #time_likes.plot(figsize =(16,4), color = 'blue')
    #plt.show()
    
    time_likes = pd.Series(data = df['Num of Likes'].values, index = df['Date'])
    time_likes.plot(figsize =(16,4), label ="Num of Likes", legend=True)
    
    time_retweets = pd.Series(data = df['Num of Retweets'].values, index = df['Date'])
    time_retweets.plot(figsize =(16,4), label ="Num of Retweets", legend=True)
    
    plt.show()
# Out:
# 96.04545454545455
# 633619
# 84675

# %% [markdown]
# #### Sentiment Analysis
# ##### whether the tweet is -ve, +ve or neutral using textblob (has build in semtiment analyzer)

# %%
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream

from tweepy import API
from tweepy import Cursor 

from textblob import TextBlob

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import re #regular expression 

#credentianls
import anfalkeys

#twitter client
class TwitterClient():
    def __init__(self, twitter_user = None):
        self.auth = Authentication().authenticate_twitter_app()
        self.twitter_client = API(self.auth)
        
        self.twitter_user = twitter_user
        
    def get_twitter_client_api(self):
        return self.twitter_client

    #funtion to get tweets
    def get_user_timeline_tweets(self, num_tweets):
        tweets =[]
        for tweet in Cursor(self.twitter_client.user_timeline, id=self.twitter_user).items(num_tweets):
            tweets.append(tweet)
        return tweets
    
    
    def get_friend_list(self, num_friends):
        friend_list=[]
        for friend in Cursor(self.twitter_client.friends, id= self.twitter_user).items(num_friends):
            friend_list.append(friends)
        return friend_list
    
    def get_home_timeline_tweets(self, num_tweets):
        home_timeline_tweets =[]
        for tweet in Cursor (self.twitter_client.home_timeline, id=self.twitter_user).items(num_tweets):
            home_timeline_tweets.append(tweet)
        return home_timeline_tweets
    
    
#authentication class
class Authentication():
    def authenticate_twitter_app(self):
        auth = OAuthHandler(anfalkeys.CONSUMER_KEY, anfalkeys.CONSUMER_SECRET)
        auth.set_access_token(anfalkeys.TOKEN_KEY, anfalkeys.TOKEN_SECRET)
        return auth
    
    
#class for streaming & processing live tweets
class TwitterStreamer ():
    def __init__(self):
        self.twitter_authenticator = Authentication()
    
    
    def stream_tweets (self, fetched_tweets_filename, hash_tag_list):
        # This handles twittter authentication & the connection to the twitter streaming api
        listener = TwitterLis(fetched_tweets_filename)
        auth = self.twitter_authenticator.authenticate_twitter_app()
        stream = Stream(auth, listener)
    
        #focused on some keywords of hashtags
        stream.filter(track=hash_tag_list)


#printing tweets & writing it into a file
class TwitterLis(StreamListener):
    def __init__ (self,fetched_tweets_filename):
        self.fetched_tweets_filename = fetched_tweets_filename
    
    def on_data(self,data): #take data that is streamed in from the stream listener so the one that's listening for tweets
        try:
            print(data)
            with open(self.fetched_tweets_filename, 'a') as tf:
                tf.write(data)
            return True
        except BaseException as e:
            print("error on data: %s" %str(e))
        return True
 
    
    def on_error(self, status): #overwriting & print the status methos 
        if status == 420:
            return False #kill connection -return false data method in case rate limit occurs
        print(status)
        
#class responsible for analyzing and categorizing tweets
class TweetAnalyzer():
       
    def clean_tweet(self, tweet):
        return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)", " ", tweet).split())

    def analyze_sentiment(self, tweet):
        analysis = TextBlob(self.clean_tweet(tweet))
        
        if analysis.sentiment.polarity > 0:
            return 1
        elif analysis.sentiment.polarity == 0:
            return 0
        else:
            return -1
  
    def tweets_to_data_frame(self, tweets):
        df = pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['tweets'])

        df['ID'] = np.array([tweet.id for tweet in tweets])
        df['Len'] = np.array([len(tweet.text) for tweet in tweets])
        df['Date'] = np.array([tweet.created_at for tweet in tweets])
        df['Source'] = np.array([tweet.source for tweet in tweets])
        df['Num of Likes'] = np.array([tweet.favorite_count for tweet in tweets])
        df['Num of Retweets'] = np.array([tweet.retweet_count for tweet in tweets])

        return df
    
if __name__ == '__main__':

    twitter_client = TwitterClient()
    tweet_analyzer = TweetAnalyzer()

    api = twitter_client.get_twitter_client_api()

    tweets = api.user_timeline(screen_name="realDonaldTrump", count=200)
    
    df = tweet_analyzer.tweets_to_data_frame(tweets)
    df['Sentiment'] = np.array([tweet_analyzer.analyze_sentiment(tweet) for tweet in df['tweets']])

    print(df.head(10))
    
 
    
    #tweets = api.user_timeline(screen_name="KylieJenner", count=200)
    #df = tweet_analyzer.tweets_to_data_frame(tweets)
    #df['Sentiment'] = np.array([tweet_analyzer.analyze_sentiment(tweet) for tweet in df['tweets']])

    #print(df.head(10))
# Out:
#                                               tweets                   ID  \
# 0  Democrats are now the party of high taxes, hig...  1185037614685904896
# 1  Tonight, we forcefully condemn the blatant cor...  1185029472132698113
# 2  The radical left tolerates no dissent, it perm...  1185026994993451008
# 3  Thank you Dallas, Texas - I love you! #TrumpRa...  1185019331018665985
# 4  Just arrived at the American Airlines Center i...  1184987864125321216
# 5  See you soon Dallas, Texas! https://t.co/Sg6xt...  1184973040150614016
# 6  RT @SarahAMatthews1: Dallas, Texas crowd is ge...  1184972554890612736
# 7  This is a great day for civilization. I am pro...  1184895160871571456
# 8  This deal could NEVER have been made 3 days ag...  1184892687587012608
# 9  Great news out of Turkey. News Conference shor...  1184884179751731200
#
#    Len                Date              Source  Num of Likes  Num of Retweets  \
# 0  140 2019-10-18 03:39:18  Twitter for iPhone         22660             7667
# 1  140 2019-10-18 03:06:57  Twitter for iPhone         25397             8587
# 2  140 2019-10-18 02:57:07  Twitter for iPhone         29478             9245
# 3   88 2019-10-18 02:26:39  Twitter for iPhone         38541            10698
# 4  140 2019-10-18 00:21:37  Twitter for iPhone         64976            16483
# 5   51 2019-10-17 23:22:43  Twitter for iPhone         45681            10810
# 6  124 2019-10-17 23:20:47  Twitter for iPhone             0            10021
# 7  139 2019-10-17 18:13:15  Twitter for iPhone        129166            31085
# 8  140 2019-10-17 18:03:25  Twitter for iPhone         91710            20431
# 9  132 2019-10-17 17:29:37  Twitter for iPhone         86756            24047
#
#    Sentiment
# 0         -1
# 1         -1
# 2         -1
# 3          1
# 4          1
# 5          0
# 6          1
# 7          1
# 8          1
# 9          1

# %% [markdown]
# #### Hashtag

# %%
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream

from tweepy import API
from tweepy import Cursor 

from textblob import TextBlob

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import re #regular expression 

#credentianls
import anfalkeys

#twitter client
class TwitterClient():
    def __init__(self, twitter_user = None):
        self.auth = Authentication().authenticate_twitter_app()
        self.twitter_client = API(self.auth)
        
        self.twitter_user = twitter_user
        
    def get_twitter_client_api(self):
        return self.twitter_client

    #funtion to get tweets
    def get_user_timeline_tweets(self, num_tweets):
        tweets =[]
        for tweet in Cursor(self.twitter_client.user_timeline, id=self.twitter_user).items(num_tweets):
            tweets.append(tweet)
        return tweets
    
    
    def get_friend_list(self, num_friends):
        friend_list=[]
        for friend in Cursor(self.twitter_client.friends, id= self.twitter_user).items(num_friends):
            friend_list.append(friends)
        return friend_list
    
    def get_home_timeline_tweets(self, num_tweets):
        home_timeline_tweets =[]
        for tweet in Cursor (self.twitter_client.home_timeline, id=self.twitter_user).items(num_tweets):
            home_timeline_tweets.append(tweet)
        return home_timeline_tweets
    
    
#authentication class
class Authentication():
    def authenticate_twitter_app(self):
        auth = OAuthHandler(anfalkeys.CONSUMER_KEY, anfalkeys.CONSUMER_SECRET)
        auth.set_access_token(anfalkeys.TOKEN_KEY, anfalkeys.TOKEN_SECRET)
        return auth
    
    
#class for streaming & processing live tweets
class TwitterStreamer ():
    def __init__(self):
        self.twitter_authenticator = Authentication()
    
    
    def stream_tweets (self, fetched_tweets_filename, hash_tag_list):
        # This handles twittter authentication & the connection to the twitter streaming api
        listener = TwitterLis(fetched_tweets_filename)
        auth = self.twitter_authenticator.authenticate_twitter_app()
        stream = Stream(auth, listener)
    
        #focused on some keywords of hashtags
        stream.filter(track=hash_tag_list)


#printing tweets & writing it into a file
class TwitterLis(StreamListener):
    def __init__ (self,fetched_tweets_filename):
        self.fetched_tweets_filename = fetched_tweets_filename
    
    def on_data(self,data): #take data that is streamed in from the stream listener so the one that's listening for tweets
        try:
            print(data)
            with open(self.fetched_tweets_filename, 'a') as tf:
                tf.write(data)
            return True
        except BaseException as e:
            print("error on data: %s" %str(e))
        return True
 
    
    def on_error(self, status): #overwriting & print the status methos 
        if status == 420:
            return False #kill connection -return false data method in case rate limit occurs
        print(status)
        
#class responsible for analyzing and categorizing tweets
class TweetAnalyzer():
       
    def clean_tweet(self, tweet):
        return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)", " ", tweet).split())

    def analyze_sentiment(self, tweet):
        analysis = TextBlob(self.clean_tweet(tweet))
        
        if analysis.sentiment.polarity > 0:
            return 1
        elif analysis.sentiment.polarity == 0:
            return 0
        else:
            return -1
  
    def tweets_to_data_frame(self, tweets):
        df = pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['tweets'])

        df['ID'] = np.array([tweet.id for tweet in tweets])
        df['Len'] = np.array([len(tweet.text) for tweet in tweets])
        df['Date'] = np.array([tweet.created_at for tweet in tweets])
        df['Source'] = np.array([tweet.source for tweet in tweets])
        df['Num of Likes'] = np.array([tweet.favorite_count for tweet in tweets])
        df['Num of Retweets'] = np.array([tweet.retweet_count for tweet in tweets])

        return df
    
if __name__ == '__main__':

    twitter_client = TwitterClient()
    tweet_analyzer = TweetAnalyzer()

    api = twitter_client.get_twitter_client_api()

   # tweets = api.user_timeline(screen_name="realDonaldTrump", count=200)
   # for tweets in tweepy.Cursor (api.search, q="#maleficent", count = 200, lang='en').items():
   #     print (tweet.created_at, tweet.text)
    tweets= api.search(q='#maleficent', count=20)
    #tweets = api.search['statuses']

    #for tweet in tweets:
          #print tweet['id_str'], '\n', tweet['text'], '\n\n\n'
    
    df = tweet_analyzer.tweets_to_data_frame(tweets)
    df['Sentiment'] = np.array([tweet_analyzer.analyze_sentiment(tweet) for tweet in df['tweets']])

    print(df.head(10))
# Out:
#                                               tweets                   ID  \
# 0  Vad underbar filmen var!!!!\n♥ ♥ ♥ ♥ ♥ ♥ ♥ ♥\n...  1185240121953542145
# 1  RT @paulinaplazas: #Maleficent is now my favor...  1185240098536919041
# 2  @JoeBiden That's good policy right there #Slee...  1185240084632625154
# 3  RT @carrhunger_ccmh: #talk while I sew in prep...  1185240076793479168
# 4       Definitely going to see #Maleficent tomorrow  1185240034133172224
# 5  Was incredible! 10/10 imo 🖤 #Maleficent #Malef...  1185240023320485895
# 6  เรามักจะเป็นผู้ร้าย ในบทสนทนาของผู้อื่นเสมอ  #...  1185240013430120448
# 7  RT @Maleficent: Critics call #Maleficent: Mist...  1185240004567584769
# 8  RT @lifeway_kefir: Well, well! #Maleficent #Ma...  1185239926541078529
# 9  RT @Maleficent: It’s time. Disney’s #Maleficen...  1185239918768869376
#
#    Len                Date               Source  Num of Likes  \
# 0  137 2019-10-18 17:04:00            Instagram             0
# 1  128 2019-10-18 17:03:54      Twitter Web App             0
# 2   68 2019-10-18 17:03:51  Twitter for Android             0
# 3  139 2019-10-18 17:03:49   Twitter for iPhone             0
# 4   44 2019-10-18 17:03:39   Twitter for iPhone             0
# 5  102 2019-10-18 17:03:36  Twitter for Android             0
# 6   98 2019-10-18 17:03:34   Twitter for iPhone             0
# 7  140 2019-10-18 17:03:32   Twitter for iPhone             0
# 8   79 2019-10-18 17:03:13  Twitter for Android             0
# 9  140 2019-10-18 17:03:11   Twitter for iPhone             0
#
#    Num of Retweets  Sentiment
# 0                0          0
# 1                7          1
# 2                0          1
# 3                1          0
# 4                0          0
# 5                0          1
# 6                0          0
# 7              657         -1
# 8                3          0
# 9               39         -1

# %%
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream

from tweepy import API
from tweepy import Cursor 

from textblob import TextBlob

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import re #regular expression 

#credentianls
import anfalkeys

#twitter client
class TwitterClient():
    def __init__(self, twitter_user = None):
        self.auth = Authentication().authenticate_twitter_app()
        self.twitter_client = API(self.auth)
        
        self.twitter_user = twitter_user
        
    def get_twitter_client_api(self):
        return self.twitter_client

    #funtion to get tweets
    def get_user_timeline_tweets(self, num_tweets):
        tweets =[]
        for tweet in Cursor(self.twitter_client.user_timeline, id=self.twitter_user).items(num_tweets):
            tweets.append(tweet)
        return tweets
    
    
    def get_friend_list(self, num_friends):
        friend_list=[]
        for friend in Cursor(self.twitter_client.friends, id= self.twitter_user).items(num_friends):
            friend_list.append(friends)
        return friend_list
    
    def get_home_timeline_tweets(self, num_tweets):
        home_timeline_tweets =[]
        for tweet in Cursor (self.twitter_client.home_timeline, id=self.twitter_user).items(num_tweets):
            home_timeline_tweets.append(tweet)
        return home_timeline_tweets
    
    
#authentication class
class Authentication():
    def authenticate_twitter_app(self):
        auth = OAuthHandler(anfalkeys.CONSUMER_KEY, anfalkeys.CONSUMER_SECRET)
        auth.set_access_token(anfalkeys.TOKEN_KEY, anfalkeys.TOKEN_SECRET)
        return auth
    
    
#class for streaming & processing live tweets
class TwitterStreamer ():
    def __init__(self):
        self.twitter_authenticator = Authentication()
    
    
    def stream_tweets (self, fetched_tweets_filename, hash_tag_list):
        # This handles twittter authentication & the connection to the twitter streaming api
        listener = TwitterLis(fetched_tweets_filename)
        auth = self.twitter_authenticator.authenticate_twitter_app()
        stream = Stream(auth, listener)
    
        #focused on some keywords of hashtags
        stream.filter(track=hash_tag_list)


#printing tweets & writing it into a file
class TwitterLis(StreamListener):
    def __init__ (self,fetched_tweets_filename):
        self.fetched_tweets_filename = fetched_tweets_filename
    
    def on_data(self,data): #take data that is streamed in from the stream listener so the one that's listening for tweets
        try:
            print(data)
            with open(self.fetched_tweets_filename, 'a') as tf:
                tf.write(data)
            return True
        except BaseException as e:
            print("error on data: %s" %str(e))
        return True
 
    
    def on_error(self, status): #overwriting & print the status methos 
        if status == 420:
            return False #kill connection -return false data method in case rate limit occurs
        print(status)
        
#class responsible for analyzing and categorizing tweets
class TweetAnalyzer():
       
    def clean_tweet(self, tweet):
        return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)", " ", tweet).split())

    def analyze_sentiment(self, tweet):
        analysis = TextBlob(self.clean_tweet(tweet))
        
        if analysis.sentiment.polarity > 0:
            return 1
        elif analysis.sentiment.polarity == 0:
            return 0
        else:
            return -1
  
    def tweets_to_data_frame(self, tweets):
        df = pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['tweets'])

        df['ID'] = np.array([tweet.id for tweet in tweets])
        df['Len'] = np.array([len(tweet.text) for tweet in tweets])
        df['Date'] = np.array([tweet.created_at for tweet in tweets])
        df['Source'] = np.array([tweet.source for tweet in tweets])
        df['Num of Likes'] = np.array([tweet.favorite_count for tweet in tweets])
        df['Num of Retweets'] = np.array([tweet.retweet_count for tweet in tweets])

        return df
    
if __name__ == '__main__':

    twitter_client = TwitterClient()
    tweet_analyzer = TweetAnalyzer()

    api = twitter_client.get_twitter_client_api()

   # tweets = api.user_timeline(screen_name="realDonaldTrump", count=200)
   # for tweets in tweepy.Cursor (api.search, q="#maleficent", count = 200, lang='en').items():
   #     print (tweet.created_at, tweet.text)
    tweets= api.search(q='#maleficent', count=20, lang='en')
    #tweets = api.search['statuses']

    #for tweet in tweets:
          #print tweet['id_str'], '\n', tweet['text'], '\n\n\n'
    
    df = tweet_analyzer.tweets_to_data_frame(tweets)
    df['Sentiment'] = np.array([tweet_analyzer.analyze_sentiment(tweet) for tweet in df['tweets']])

    print(df.head(10))
# Out:
#                                               tweets                   ID  \
# 0  RT @KINGDOMHEARTS: Darkness is coming…\n \nSee...  1185276236756471808
# 1  RT @Maleficent: Well, well… Have you gotten yo...  1185276231928803328
# 2  Listen to I wanna feel your body(Original Mix)...  1185276231387963392
# 3  RT @wickedjolie: 5 years ago, Angelina Jolie's...  1185276115557990401
# 4  RT @KINGDOMHEARTS: Darkness is coming…\n \nSee...  1185276112214970369
# 5  RT @KINGDOMHEARTS: Darkness is coming…\n \nSee...  1185276069315784705
# 6  RT @Maleficent: Well, well… Have you gotten yo...  1185276069156413440
# 7  RT @DisneyStudios: It’s time. Disney’s #Malefi...  1185276055298269184
# 8  RT @RemiHoliday: DO NOT SEE MOVIES BASED ON CR...  1185276033622102017
# 9  RT @DisneyStudios: That #FridayFeeling when #M...  1185276030908387331
#
#    Len                Date               Source  Num of Likes  \
# 0  140 2019-10-18 19:27:30  Twitter for Android             0
# 1  122 2019-10-18 19:27:29  Twitter for Android             0
# 2  137 2019-10-18 19:27:29  Twitter for Android             0
# 3  140 2019-10-18 19:27:01      Twitter Web App             0
# 4  140 2019-10-18 19:27:01      Twitter Web App             0
# 5  140 2019-10-18 19:26:50  Twitter for Android             0
# 6  122 2019-10-18 19:26:50   Twitter for iPhone             0
# 7  140 2019-10-18 19:26:47      Twitter Web App             0
# 8  109 2019-10-18 19:26:42  Twitter for Android             0
# 9  123 2019-10-18 19:26:41   Twitter for iPhone             0
#
#    Num of Retweets  Sentiment
# 0              146          1
# 1               58         -1
# 2                0          1
# 3              276          1
# 4              147          1
# 5              147          1
# 6               58         -1
# 7               51         -1
# 8               22          0
# 9              169         -1

# %% [markdown]
# #### Sample search "tweets.json"

# %%
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream

from tweepy import API
from tweepy import Cursor 

from textblob import TextBlob

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import re #regular expression

#credentianls
import anfalkeys
import json

#twitter client
class TwitterClient():
    def __init__(self, twitter_user = None):
        self.auth = Authentication().authenticate_twitter_app()
        self.twitter_client = API(self.auth)
        
        self.twitter_user = twitter_user
        
    def get_twitter_client_api(self):
        return self.twitter_client

    #funtion to get tweets
    def get_user_timeline_tweets(self, num_tweets):
        tweets =[]
        for tweet in Cursor(self.twitter_client.user_timeline, id=self.twitter_user).items(num_tweets):
            tweets.append(tweet)
        return tweets
    
    
    def get_friend_list(self, num_friends):
        friend_list=[]
        for friend in Cursor(self.twitter_client.friends, id= self.twitter_user).items(num_friends):
            friend_list.append(friends)
        return friend_list
    
    def get_home_timeline_tweets(self, num_tweets):
        home_timeline_tweets =[]
        for tweet in Cursor (self.twitter_client.home_timeline, id=self.twitter_user).items(num_tweets):
            home_timeline_tweets.append(tweet)
        return home_timeline_tweets
    
    
#authentication class
class Authentication():
    def authenticate_twitter_app(self):
        auth = OAuthHandler(anfalkeys.CONSUMER_KEY, anfalkeys.CONSUMER_SECRET)
        auth.set_access_token(anfalkeys.TOKEN_KEY, anfalkeys.TOKEN_SECRET)
        return auth
    
    
#class for streaming & processing live tweets
class TwitterStreamer ():
    def __init__(self):
        self.twitter_authenticator = Authentication()
    
    
    def stream_tweets (self, fetched_tweets_filename, hash_tag_list):
        # This handles twittter authentication & the connection to the twitter streaming api
        listener = TwitterLis(fetched_tweets_filename)
        auth = self.twitter_authenticator.authenticate_twitter_app()
        stream = Stream(auth, listener)
    
        #focused on some keywords of hashtags
        stream.filter(track=hash_tag_list)


#printing tweets & writing it into a file
class TwitterLis(StreamListener):
    def __init__ (self,fetched_tweets_filename):
        self.fetched_tweets_filename = fetched_tweets_filename
    
    def on_data(self,data): #take data that is streamed in from the stream listener so the one that's listening for tweets
        try:
            print(data)
            with open(self.fetched_tweets_filename, 'a') as tf:
                tf.write(data)
            return True
        except BaseException as e:
            print("error on data: %s" %str(e))
        return True
 
    
    def on_error(self, status): #overwriting & print the status methos 
        if status == 420:
            return False #kill connection -return false data method in case rate limit occurs
        print(status)
        
#class responsible for analyzing and categorizing tweets
class TweetAnalyzer():
       
    def clean_tweet(self, tweet):
        return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)", " ", tweet).split())

    def analyze_sentiment(self, tweet):
        analysis = TextBlob(self.clean_tweet(tweet))
        
        if analysis.sentiment.polarity > 0:
            return 1
        elif analysis.sentiment.polarity == 0:
            return 0
        else:
            return -1
  
    def tweets_to_data_frame(self, tweets):
        df = pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['tweets'])

        df['ID'] = np.array([tweet.id for tweet in tweets])
        df['Len'] = np.array([len(tweet.text) for tweet in tweets])
        df['Date'] = np.array([tweet.created_at for tweet in tweets])
        df['Source'] = np.array([tweet.source for tweet in tweets])
        df['Num of Likes'] = np.array([tweet.favorite_count for tweet in tweets])
        df['Num of Retweets'] = np.array([tweet.retweet_count for tweet in tweets])

        return df
    
if __name__ == '__main__':

    twitter_client = TwitterClient()
    tweet_analyzer = TweetAnalyzer()

    api = twitter_client.get_twitter_client_api()
###reading from json

#prompt the user for a file to import
filter = "tweets"
filename = rs.OpenFileName("Open JSON File", filter)

#Read JSON data into the datastore variable
if filename:
    with open(tweets, 'r') as f:
        datastore = json.load(f)

    
    df = tweet_analyzer.tweets_to_data_frame(tweets)
    df['Sentiment'] = np.array([tweet_analyzer.analyze_sentiment(tweet) for tweet in df['tweets']])

    print(df.head(10))
